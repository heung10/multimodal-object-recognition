# %% [markdown]
# ## Object selectivity
# This code defines object selectivity based on beta coefficients in multiple linear regression model. Specifically, object selectivity to visual or auditory modality is defined by the differences in beta coefficients within a modality (i.e., Boy image vs. Egg image for visual).

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd

from scipy import stats
from scipy.ndimage import gaussian_filter

import matplotlib as mpl
import matplotlib.pyplot as plt  
import matplotlib.patches as mpatches

from datetime import date
import time

from joblib import Parallel, delayed

import h5py

# %%
# no top and right spines in all plots
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
mother_path = Path('D:/Multi-modal project/')

# %% [markdown]
# ### Parameter setting

# %%
alpha = 0.05
cons_bin_crit = 5

gauss_sigma = 2

# colors for multimodal, vis-only, aud-only conditions
color = ['mediumorchid','cornflowerblue','lightcoral','gray']
color2 = ['cyan','magenta','gray']
linestyle = ['-',':']

today = str(date.today())

# %% [markdown]
# ### Data preparation

# %%
save_path = mother_path /'analysis'/'result'/'4. Object selectivity'/today
cell_path = mother_path/'analysis'/'result'/'zFR export'/'13-Apr-2022 (5 trials)'
data_path = mother_path /'analysis'/'result'/'3. Multiple linear regression'

cell_list = os.listdir(cell_path)

# load hdf5 files containing shuffled results
f = h5py.File(data_path/'2023-05-12'/'2023-05-12_multiple_regression_result.hdf5','r')

# make hdf5 save file
os.makedirs(save_path,exist_ok=True)
s = h5py.File(save_path/f'{today}_object_selectivity_result.hdf5','w')

# %% [markdown]
# # Data analysis

# %%
def consecutive_bin(sig_bin,cons_bin_crit):
    diff = np.diff(sig_bin)
    array_split = np.split(sig_bin,np.where(diff!=1)[0]+1)
    filtered = [a for a in array_split if len(a)>=cons_bin_crit]
    if len(filtered)!=0:
        result = np.concatenate(filtered)    
    else:
        result = np.array([])
    return result

# %%
def plot_SDF_beta(df,linewidth,smooth,save,save_format):
    """
    This function plots mean firing rate patterns of each stimulus condition
    and beta coefficients for visual and auditory terms in multiple linear regression.
    """
    cond = [(df.Type=='Multimodal')&(df.RWD_Loc==boy_goal),
            (df.Type=='Multimodal')&(df.RWD_Loc==egg_goal),
            (df.Type=='Visual')&(df.RWD_Loc==boy_goal),
            (df.Type=='Visual')&(df.RWD_Loc==egg_goal),
            (df.Type=='Auditory')&(df.RWD_Loc==boy_goal),
            (df.Type=='Auditory')&(df.RWD_Loc==egg_goal),
            (df.Type=='Elemental')&(df.RWD_Loc==boy_goal),
            (df.Type=='Elemental')&(df.RWD_Loc==egg_goal)]
    
    cell_full_name = cell_name.strip('.csv')
    
    fr_mean = np.zeros((len(cond),95))
    fr_sem = np.zeros((len(cond),95))
    for i in range(len(cond)):
        fr_mean[i,:] = df[cond[i]].iloc[:,fr_id:fr_id+95].to_numpy().mean(axis=0)
        fr_sem[i,:] = stats.sem(df[cond[i]].iloc[:,fr_id:fr_id+95].to_numpy())
    
    if smooth:
        for i in range(len(cond)):
            fr_mean[i,:] = gaussian_filter(fr_mean[i,:],sigma=gauss_sigma)
            fr_sem[i,:] = gaussian_filter(fr_sem[i,:],sigma=gauss_sigma)
            
    y_max = np.ceil(np.max(fr_mean+fr_sem))
    y_min = np.ceil(np.abs(np.min(fr_mean-fr_sem)))*-1
    
    fig,ax = plt.subplots(3,3,figsize=(15,10))
    plt.suptitle(cell_full_name,fontsize=15);
    x = np.arange(95)*10
    
    for i in range(len(cond)-2):
        if i%2==0:
            ls = linestyle[0]
        else:
            ls = linestyle[1]            
        ax[0,0].plot(x,fr_mean[i,:],color=color[int(np.floor(i/2))],linewidth=linewidth,linestyle=ls)
        ax[0,0].fill_between(x,fr_mean[i,:]-fr_sem[i,:],fr_mean[i,:]+fr_sem[i,:],color=color[int(np.floor(i/2))],alpha=0.2)
        
        ax[i%2+1,0].plot(x,fr_mean[i,:],color=color[int(np.floor(i/2))],linewidth=linewidth,linestyle=ls)
        ax[i%2+1,0].fill_between(x,fr_mean[i,:]-fr_sem[i,:],fr_mean[i,:]+fr_sem[i,:],color=color[int(np.floor(i/2))],alpha=0.2)
        
        if i<6:
            ax[int(np.floor(i/2)),1].plot(x,fr_mean[i,:],color=color[int(np.floor(i/2))],linewidth=linewidth,linestyle=ls)
            ax[int(np.floor(i/2)),1].fill_between(x,fr_mean[i,:]-fr_sem[i,:],fr_mean[i,:]+fr_sem[i,:],color=color[int(np.floor(i/2))],alpha=0.2)
    
    # control stimulus SDF
    #for i in range(3):
    #    ax[i,1].plot(x,fr_mean[6,:],color=color[3])
    #    ax[i,1].plot(x,fr_mean[7,:],color=color[3],linestyle=':')
    
    # SDF for each condition
    t1 = ['All conditions','Boy condition','Egg condition','Multimodal','Visual-only','Auditory-only']
    for i in range(6):
        ax[i%3,int(np.floor(i/3))].scatter(visual_bin*10,np.tile(y_max-0.1,(len(visual_bin),1)),
                                           color=color2[0],marker='*',s=5)
        ax[i%3,int(np.floor(i/3))].scatter(auditory_bin*10,np.tile(y_max-0.3,(len(auditory_bin),1)),
                                           color=color2[1],marker='*',s=5)
        ax[i%3,int(np.floor(i/3))].set_title(t1[i],fontsize=13)
        ax[i%3,int(np.floor(i/3))].set_yticks(np.arange(y_min,y_max+0.1,1))
        ax[i%3,int(np.floor(i/3))].set_ylabel('z-scored FR',fontsize=13)
        ax[i%3,int(np.floor(i/3))].set_xlabel('Time (ms)',fontsize=13)  
        ax[i%3,int(np.floor(i/3))].set_xticks([0,400,950])
        ax[i%3,int(np.floor(i/3))].set_xlim([0,950])    
    
    if smooth:
        for i in range(len(beta_coef)):
            beta_coef[i,:] = gaussian_filter(beta_coef[i,:],sigma=gauss_sigma)
    
    beta_max = np.ceil(np.max(beta_coef))
    beta_min = np.ceil(np.abs(np.min(beta_coef)))*-1
    
    # beta coefficient plot
    t2 = ['Visual term','Auditory term','Interaction term']
    ax[0,2].scatter(visual_bin*10,np.tile(beta_max-0.1,(len(visual_bin),1)),color=color2[0],marker='*',s=5)
    ax[1,2].scatter(auditory_bin*10,np.tile(beta_max-0.1,(len(auditory_bin),1)),color=color2[1],marker='*',s=5)    
    for i in range(3):
        ax[i,2].plot(x,beta_coef[i,:],color=color2[i],linestyle='-',linewidth=linewidth)
        ax[i,2].plot(x,beta_coef[i+3,:],color=color2[i],linestyle=':',linewidth=linewidth)    
            
        ax[i,2].set_title(t2[i],fontsize=13)
        ax[i,2].set_yticks(np.arange(beta_min,beta_max+0.1,0.5))    
        ax[i,2].set_ylabel('Beta coefficient',fontsize=13)
        ax[i,2].set_xlabel('Time (ms)',fontsize=13)    
        ax[i,2].set_xticks([0,400,950])
        ax[i,2].set_xlim([0,950])
        
    plt.tight_layout()
    
    if save:
        fig_path = save_path / region / cat
        os.makedirs(fig_path, exist_ok=True)

        if save_format == 'png':
            plt.savefig(fig_path / f'{cell_full_name}.png', dpi=100, facecolor='white')
        elif save_format == 'svg':
            plt.savefig(fig_path / f'{cell_full_name}.svg')
        plt.close()

# %%
def save_result(f):
    """
    This function saves regression results into HDF5 format.
    """
    cell_group = f.create_group(str(cell_id))
    
    cell_group.create_dataset('visual_coef',data=visual)
    cell_group.create_dataset('auditory_coef',data=auditory)   
    cell_group.create_dataset('visual_crit',data=visual_crit)
    cell_group.create_dataset('auditory_crit',data=auditory_crit)
    cell_group.create_dataset('visual_bin',data=visual_bin)
    cell_group.create_dataset('auditory_bin',data=auditory_bin)
    cell_group.create_dataset('visual_peak',data=visual_peak)
    cell_group.create_dataset('auditory_peak',data=auditory_peak)
    
    cell_group.attrs['Rat'] = rat_id
    cell_group.attrs['Region'] = region
    cell_group.attrs['Session'] = session_id
    cell_group.attrs['Category'] = cat

# %%
# %%time
for cell_run,cell_name in enumerate(cell_list):
    loop_start = time.time()
    # get information about the cell
    cell_info = cell_name.split('-')
    cell_id, rat_id, session_id, region = int(cell_info[0]), cell_info[1], cell_info[2], cell_info[5]
    
    # skip response-selective cell
    if f[str(cell_id)].attrs['Response cell'] == 1:
        continue
    
    # load cell data
    df = pd.read_csv(cell_path/cell_name)
    df.drop(df[df.Correctness==0].index,inplace=True)
    df.reset_index(inplace=True,drop=True)
    df[['Visual','Auditory']] = df[['Visual','Auditory']].fillna('no')
    
    boy_goal = df.loc[df['Visual']=='Boy','RWD_Loc'].values[0]
    boy_aud = df.loc[df['RWD_Loc']==boy_goal,'Auditory'].values[0]
    
    egg_goal = df.loc[df['Visual']=='Egg','RWD_Loc'].values[0]
    egg_aud = df.loc[df['RWD_Loc']==egg_goal,'Auditory'].values[0]
    
    fr_id = df.columns.get_loc('Var10')  # get the index of the first firing rate column
    
    # load beta coefficient
    beta_coef = np.array(f[f'{cell_id}/basic/beta_coef'])
    beta_coef_shuffle = np.array(f[f'{cell_id}/basic_shuffle/beta_coef'])
    
    # define significant selectivity based on shuffled distribution
    visual = np.subtract(beta_coef[0,:],beta_coef[3,:])
    auditory = np.subtract(beta_coef[1,:],beta_coef[4,:])
    
    visual_shuffle = np.subtract(beta_coef_shuffle[:,0,:],beta_coef_shuffle[:,3,:])
    auditory_shuffle = np.subtract(beta_coef_shuffle[:,1,:],beta_coef_shuffle[:,4,:])    
    
    visual_crit = [np.percentile(np.ravel(visual_shuffle),alpha*50), np.percentile(np.ravel(visual_shuffle),100-alpha*50)]
    auditory_crit = [np.percentile(np.ravel(auditory_shuffle),alpha*50), np.percentile(np.ravel(auditory_shuffle),100-alpha*50)]

    visual_bin = np.where((visual<visual_crit[0])|(visual>visual_crit[1]))[0]
    auditory_bin = np.where((auditory<auditory_crit[0])|(auditory>auditory_crit[1]))[0]

    visual_bin = consecutive_bin(visual_bin,cons_bin_crit)
    auditory_bin = consecutive_bin(auditory_bin,cons_bin_crit)
    
    # find bin with maximum selectivity
    visual_peak = visual_bin[np.argmax(np.abs(beta_coef[0, visual_bin] - beta_coef[3, visual_bin]))] if len(visual_bin) != 0 else []
    auditory_peak = auditory_bin[np.argmax(np.abs(beta_coef[1, auditory_bin] - beta_coef[4, auditory_bin]))] if len(auditory_bin) != 0 else []
    
    # categorize a neuron based on coding modality
    if len(visual_bin) != 0 and len(auditory_bin) != 0:
        cat = 'multimodal'
    elif len(visual_bin) != 0:
        cat = 'visual'
    elif len(auditory_bin) != 0:
        cat = 'auditory'
    else:
        cat = 'none'         
        
    # plot SDF and beta coefficient + mark bins with significant selectivity    
    plot_SDF_beta(df,2,1,1,'png')
    
    # save results into HDF5 format
    save_result(s)    
                
    loop_end = time.time()
    loop_time = divmod(loop_end-loop_start,60)
    print(cell_name.strip('.csv'), f'////// {cell_run+1}/{len(cell_list)} completed  //////  {int(loop_time[0])} min {loop_time[1]:.2f} sec')
# Out:
# 0003-600-1-1-Crossmodal-TeV-deep-(-7.32 mm)-TT4.1 ////// 1/878 completed  //////  0 min 1.03 sec
# 0004-600-1-1-Crossmodal-TeV-deep-(-7.32 mm)-TT4.2 ////// 2/878 completed  //////  0 min 0.97 sec
# 0005-600-1-1-Crossmodal-TeV-deep-(-7.32 mm)-TT4.3 ////// 3/878 completed  //////  0 min 0.95 sec
# 0006-600-1-1-Crossmodal-PER-superficial-(-7.2 mm)-TT5.1 ////// 4/878 completed  //////  0 min 0.98 sec
# 0007-600-1-1-Crossmodal-PER-superficial-(-7.2 mm)-TT5.2 ////// 5/878 completed  //////  0 min 0.95 sec
# 0008-600-1-1-Crossmodal-PER-superficial-(-7.2 mm)-TT5.3 ////// 6/878 completed  //////  0 min 0.87 sec
# 0010-600-1-1-Crossmodal-TeV-deep-(-6.96 mm)-TT6.2 ////// 7/878 completed  //////  0 min 0.89 sec
# 0011-600-1-1-Crossmodal-PER-superficial-(-6.48 mm)-TT7.1 ////// 8/878 completed  //////  0 min 0.99 sec
# 0013-600-1-1-Crossmodal-PER-deep-(-6.48 mm)-TT8.2 ////// 9/878 completed  //////  0 min 0.83 sec
# 0014-600-1-1-Crossmodal-PER-deep-(-6.48 mm)-TT8.3 ////// 10/878 completed  //////  0 min 0.88 sec
# 0015-600-1-1-Crossmodal-TeV-deep-(-6.36 mm)-TT9.1 ////// 11/878 completed  //////  0 min 0.79 sec
# 0016-600-1-1-Crossmodal-PER-deep-(-6.24 mm)-TT10.1 ////// 12/878 completed  //////  0 min 1.26 sec
# 0017-600-1-1-Crossmodal-PER-deep-(-6.24 mm)-TT10.2 ////// 13/878 completed  //////  0 min 1.02 sec
# 0018-600-1-1-Crossmodal-PER-superficial-(-6.24 mm)-TT13.1 ////// 14/878 completed  //////  0 min 1.03 sec
# 0021-600-1-1-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.1 ////// 15/878 completed  //////  0 min 1.13 sec
# 0022-600-1-1-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.2 ////// 16/878 completed  //////  0 min 1.00 sec
# 0023-600-1-1-Crossmodal-POR-deep-(-7.56 mm)-TT24.1 ////// 17/878 completed  //////  0 min 1.27 sec
# 0024-600-1-1-Crossmodal-POR-deep-(-7.56 mm)-TT24.2 ////// 18/878 completed  //////  0 min 0.91 sec
# 0025-600-1-1-Crossmodal-POR-deep-(-7.56 mm)-TT24.3 ////// 19/878 completed  //////  0 min 0.83 sec
# 0026-600-2-2-Crossmodal-TeV-deep-(-7.32 mm)-TT4.1 ////// 20/878 completed  //////  0 min 0.95 sec
# 0027-600-2-2-Crossmodal-PER-superficial-(-7.2 mm)-TT5.1 ////// 21/878 completed  //////  0 min 0.90 sec
# 0028-600-2-2-Crossmodal-PER-superficial-(-7.2 mm)-TT5.2 ////// 22/878 completed  //////  0 min 0.88 sec
# 0029-600-2-2-Crossmodal-PER-superficial-(-7.2 mm)-TT5.3 ////// 23/878 completed  //////  0 min 1.06 sec
# 0030-600-2-2-Crossmodal-PER-superficial-(-7.2 mm)-TT5.4 ////// 24/878 completed  //////  0 min 0.91 sec
# 0031-600-2-2-Crossmodal-TeV-deep-(-6.96 mm)-TT6.1 ////// 25/878 completed  //////  0 min 0.91 sec
# 0032-600-2-2-Crossmodal-TeV-deep-(-6.96 mm)-TT6.2 ////// 26/878 completed  //////  0 min 0.81 sec
# 0033-600-2-2-Crossmodal-PER-superficial-(-6.48 mm)-TT7.1 ////// 27/878 completed  //////  0 min 0.83 sec
# 0035-600-2-2-Crossmodal-PER-superficial-(-6.48 mm)-TT7.3 ////// 28/878 completed  //////  0 min 0.90 sec
# 0036-600-2-2-Crossmodal-PER-superficial-(-6.48 mm)-TT7.4 ////// 29/878 completed  //////  0 min 0.86 sec
# 0037-600-2-2-Crossmodal-PER-deep-(-6.48 mm)-TT8.1 ////// 30/878 completed  //////  0 min 1.23 sec
# 0038-600-2-2-Crossmodal-PER-deep-(-6.48 mm)-TT8.2 ////// 31/878 completed  //////  0 min 0.92 sec
# 0039-600-2-2-Crossmodal-PER-deep-(-6.24 mm)-TT10.1 ////// 32/878 completed  //////  0 min 1.03 sec
# 0040-600-2-2-Crossmodal-PER-superficial-(-7.24 mm)-TT13.1 ////// 33/878 completed  //////  0 min 0.79 sec
# 0041-600-2-2-Crossmodal-PER-superficial-(-6.36 mm)-TT15.1 ////// 34/878 completed  //////  0 min 0.80 sec
# 0042-600-2-2-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.1 ////// 35/878 completed  //////  0 min 0.81 sec
# 0043-600-2-2-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.2 ////// 36/878 completed  //////  0 min 1.05 sec
# 0047-600-2-2-Crossmodal-POR-deep-(-7.56 mm)-TT24.2 ////// 40/878 completed  //////  0 min 0.86 sec
# 0048-600-2-2-Crossmodal-POR-deep-(-7.56 mm)-TT24.3 ////// 41/878 completed  //////  0 min 0.88 sec
# 0049-600-3-3-Crossmodal-PER-superficial-(-7.2 mm)-TT5.1 ////// 42/878 completed  //////  0 min 0.78 sec
# 0050-600-3-3-Crossmodal-PER-superficial-(-7.2 mm)-TT5.2 ////// 43/878 completed  //////  0 min 1.42 sec
# 0051-600-3-3-Crossmodal-PER-superficial-(-7.2 mm)-TT5.3 ////// 44/878 completed  //////  0 min 0.83 sec
# 0052-600-3-3-Crossmodal-PER-superficial-(-6.48 mm)-TT7.1 ////// 45/878 completed  //////  0 min 0.77 sec
# 0053-600-3-3-Crossmodal-PER-superficial-(-6.48 mm)-TT7.2 ////// 46/878 completed  //////  0 min 0.78 sec
# 0056-600-3-3-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.1 ////// 47/878 completed  //////  0 min 0.86 sec
# 0057-600-3-3-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.2 ////// 48/878 completed  //////  0 min 0.80 sec
# 0058-600-3-3-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.3 ////// 49/878 completed  //////  0 min 0.93 sec
# 0059-600-3-3-Crossmodal-POR-deep-(-7.56 mm)-TT24.1 ////// 50/878 completed  //////  0 min 0.83 sec
# 0061-600-4-4-Crossmodal-PER-superficial-(-7.2 mm)-TT5.1 ////// 52/878 completed  //////  0 min 1.02 sec
# 0062-600-4-4-Crossmodal-PER-superficial-(-7.2 mm)-TT5.2 ////// 53/878 completed  //////  0 min 0.85 sec
# 0063-600-4-4-Crossmodal-PER-deep-(-6.96 mm)-TT6.1 ////// 54/878 completed  //////  0 min 0.81 sec
# 0065-600-4-4-Crossmodal-PER-superficial-(-6.48 mm)-TT7.1 ////// 55/878 completed  //////  0 min 1.44 sec
# 0066-600-4-4-Crossmodal-PER-superficial-(-6.48 mm)-TT7.2 ////// 56/878 completed  //////  0 min 0.84 sec
# 0067-600-4-4-Crossmodal-PER-superficial-(-6.48 mm)-TT7.3 ////// 57/878 completed  //////  0 min 0.78 sec
# 0068-600-4-4-Crossmodal-PER-deep-(-6.36 mm)-TT9.1 ////// 58/878 completed  //////  0 min 0.93 sec
# 0069-600-4-4-Crossmodal-PER-deep-(-6.36 mm)-TT9.2 ////// 59/878 completed  //////  0 min 0.82 sec
# 0070-600-4-4-Crossmodal-PER-deep-(-6.24 mm)-TT10.1 ////// 60/878 completed  //////  0 min 0.85 sec
# 0071-600-4-4-Crossmodal-PER-deep-(-6.24 mm)-TT10.2 ////// 61/878 completed  //////  0 min 0.80 sec
# 0072-600-4-4-Crossmodal-PER-superficial-(-9.24 mm)-TT13.1 ////// 62/878 completed  //////  0 min 0.84 sec
# 0073-600-4-4-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.1 ////// 63/878 completed  //////  0 min 0.87 sec
# 0074-600-4-4-Crossmodal-TeV-deep-(-6.96 mm)-TT19.1 ////// 64/878 completed  //////  0 min 0.81 sec
# 0075-600-4-4-Crossmodal-POR-deep-(-7.56 mm)-TT24.1 ////// 65/878 completed  //////  0 min 0.79 sec
# 0076-600-4-4-Crossmodal-POR-deep-(-7.56 mm)-TT24.2 ////// 66/878 completed  //////  0 min 0.81 sec
# 0079-600-4-4-Crossmodal-POR-deep-(-7.56 mm)-TT24.5 ////// 69/878 completed  //////  0 min 0.93 sec
# 0081-600-5-5-Crossmodal-PER-superficial-(-7.2 mm)-TT5.2 ////// 70/878 completed  //////  0 min 1.05 sec
# 0082-600-5-5-Crossmodal-PER-superficial-(-7.2 mm)-TT5.3 ////// 71/878 completed  //////  0 min 1.79 sec
# 0083-600-5-5-Crossmodal-PER-superficial-(-7.2 mm)-TT5.4 ////// 72/878 completed  //////  0 min 0.93 sec
# 0084-600-5-5-Crossmodal-PER-superficial-(-6.48 mm)-TT7.1 ////// 73/878 completed  //////  0 min 0.87 sec
# 0085-600-5-5-Crossmodal-PER-deep-(-6.36 mm)-TT9.1 ////// 74/878 completed  //////  0 min 0.75 sec
# 0086-600-5-5-Crossmodal-PER-deep-(-6.24 mm)-TT10.1 ////// 75/878 completed  //////  0 min 0.82 sec
# 0087-600-5-5-Crossmodal-PER-deep-(-6.24 mm)-TT10.2 ////// 76/878 completed  //////  0 min 0.84 sec
# 0088-600-5-5-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.1 ////// 77/878 completed  //////  0 min 0.79 sec
# 0089-600-5-5-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.2 ////// 78/878 completed  //////  0 min 0.78 sec
# 0090-600-5-5-Crossmodal-TeV-deep-(-6.96 mm)-TT19.1 ////// 79/878 completed  //////  0 min 0.87 sec
# 0091-600-5-5-Crossmodal-TeV-deep-(-7.44 mm)-TT21.1 ////// 80/878 completed  //////  0 min 0.94 sec
# 0092-600-5-5-Crossmodal-POR-deep-(-7.56 mm)-TT24.1 ////// 81/878 completed  //////  0 min 0.83 sec
# 0093-600-5-5-Crossmodal-POR-deep-(-7.56 mm)-TT24.2 ////// 82/878 completed  //////  0 min 0.72 sec
# 0094-600-5-5-Crossmodal-POR-deep-(-7.56 mm)-TT24.3 ////// 83/878 completed  //////  0 min 0.81 sec
# 0095-600-5-5-Crossmodal-POR-deep-(-7.56 mm)-TT24.4 ////// 84/878 completed  //////  0 min 0.82 sec
# 0096-600-5-5-Crossmodal-POR-deep-(-7.56 mm)-TT24.5 ////// 85/878 completed  //////  0 min 0.84 sec
# 0174-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.1 ////// 86/878 completed  //////  0 min 0.72 sec
# 0175-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.10 ////// 87/878 completed  //////  0 min 0.89 sec
# 0176-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.11 ////// 88/878 completed  //////  0 min 0.85 sec
# 0177-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.2 ////// 89/878 completed  //////  0 min 1.97 sec
# 0178-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.3 ////// 90/878 completed  //////  0 min 0.88 sec
# 0179-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.4 ////// 91/878 completed  //////  0 min 0.78 sec
# 0181-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.6 ////// 92/878 completed  //////  0 min 0.93 sec
# 0182-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.7 ////// 93/878 completed  //////  0 min 0.79 sec
# 0183-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.8 ////// 94/878 completed  //////  0 min 0.86 sec
# 0184-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.9 ////// 95/878 completed  //////  0 min 0.81 sec
# 0185-602-1-1-Crossmodal-PER-deep-(-4.8 mm)-TT7.1 ////// 96/878 completed  //////  0 min 0.90 sec
# 0188-602-1-1-Crossmodal-TeV-deep-(-4.44 mm)-TT9.2 ////// 97/878 completed  //////  0 min 0.82 sec
# 0190-602-1-1-Crossmodal-TeV-deep-(-4.44 mm)-TT9.4 ////// 98/878 completed  //////  0 min 0.83 sec
# 0191-602-1-1-Crossmodal-TeV-deep-(-4.44 mm)-TT9.5 ////// 99/878 completed  //////  0 min 0.76 sec
# 0192-602-1-1-Crossmodal-TeV-deep-(-4.44 mm)-TT9.6 ////// 100/878 completed  //////  0 min 0.91 sec
# 0193-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.1 ////// 101/878 completed  //////  0 min 0.77 sec
# 0194-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.2 ////// 102/878 completed  //////  0 min 0.79 sec
# 0195-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.3 ////// 103/878 completed  //////  0 min 0.75 sec
# 0196-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.4 ////// 104/878 completed  //////  0 min 0.95 sec
# 0197-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.5 ////// 105/878 completed  //////  0 min 0.76 sec
# 0198-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.6 ////// 106/878 completed  //////  0 min 0.87 sec
# 0200-602-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 107/878 completed  //////  0 min 0.79 sec
# 0201-602-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 108/878 completed  //////  0 min 1.03 sec
# 0202-602-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.4 ////// 109/878 completed  //////  0 min 0.88 sec
# 0203-602-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.5 ////// 110/878 completed  //////  0 min 0.85 sec
# 0205-602-1-1-Crossmodal-PER-superficial-(-4.2 mm)-TT12.2 ////// 112/878 completed  //////  0 min 2.12 sec
# 0207-602-1-1-Crossmodal-Auditory-superficial-(-5.52 mm)-TT19.2 ////// 113/878 completed  //////  0 min 0.86 sec
# 0208-602-1-1-Crossmodal-Auditory-superficial-(-5.52 mm)-TT19.3 ////// 114/878 completed  //////  0 min 0.85 sec
# 0209-602-1-1-Crossmodal-TeV-superficial-(-5.52 mm)-TT20.1 ////// 115/878 completed  //////  0 min 0.82 sec
# 0210-602-1-1-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.1 ////// 116/878 completed  //////  0 min 0.82 sec
# 0211-602-1-1-Crossmodal-PER-superficial-(-5.4 mm)-TT22.1 ////// 117/878 completed  //////  0 min 0.78 sec
# 0212-602-1-1-Crossmodal-PER-superficial-(-5.4 mm)-TT22.2 ////// 118/878 completed  //////  0 min 0.73 sec
# 0214-602-1-1-Crossmodal-PER-superficial-(-5.4 mm)-TT22.4 ////// 119/878 completed  //////  0 min 0.87 sec
# 0215-602-1-1-Crossmodal-TeV-superficial-(-5.52 mm)-TT24.1 ////// 120/878 completed  //////  0 min 0.77 sec
# 0216-602-1-1-Crossmodal-TeV-superficial-(-5.52 mm)-TT24.2 ////// 121/878 completed  //////  0 min 0.82 sec
# 0217-602-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT4.1 ////// 122/878 completed  //////  0 min 0.80 sec
# 0218-602-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT6.1 ////// 123/878 completed  //////  0 min 0.77 sec
# 0220-602-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT6.3 ////// 124/878 completed  //////  0 min 0.91 sec
# 0222-602-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT6.5 ////// 125/878 completed  //////  0 min 0.96 sec
# 0223-602-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT6.6 ////// 126/878 completed  //////  0 min 0.86 sec
# 0224-602-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT7.1 ////// 127/878 completed  //////  0 min 0.91 sec
# 0227-602-2-2-Crossmodal-PER-superficial-(-4.8 mm)-TT8.3 ////// 128/878 completed  //////  0 min 0.95 sec
# 0228-602-2-2-Crossmodal-TeV-deep-(-4.44 mm)-TT9.1 ////// 129/878 completed  //////  0 min 0.88 sec
# 0230-602-2-2-Crossmodal-TeV-deep-(-4.44 mm)-TT9.3 ////// 130/878 completed  //////  0 min 0.73 sec
# 0233-602-2-2-Crossmodal-TeV-deep-(-4.44 mm)-TT9.6 ////// 132/878 completed  //////  0 min 0.90 sec
# 0234-602-2-2-Crossmodal-TeV-deep-(-4.44 mm)-TT9.7 ////// 133/878 completed  //////  0 min 0.85 sec
# 0235-602-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT10.1 ////// 134/878 completed  //////  0 min 0.87 sec
# 0236-602-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT10.2 ////// 135/878 completed  //////  0 min 0.77 sec
# 0237-602-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT10.3 ////// 136/878 completed  //////  0 min 0.84 sec
# 0238-602-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT10.4 ////// 137/878 completed  //////  0 min 0.84 sec
# 0239-602-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.1 ////// 138/878 completed  //////  0 min 0.85 sec
# 0240-602-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 139/878 completed  //////  0 min 0.77 sec
# 0241-602-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 140/878 completed  //////  0 min 2.44 sec
# 0242-602-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.4 ////// 141/878 completed  //////  0 min 0.81 sec
# 0247-602-2-2-Crossmodal-PER-superficial-(-4.2 mm)-TT12.5 ////// 143/878 completed  //////  0 min 0.89 sec
# 0251-602-2-2-Crossmodal-Auditory-superficial-(-5.52 mm)-TT19.1 ////// 144/878 completed  //////  0 min 0.76 sec
# 0254-602-2-2-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.3 ////// 145/878 completed  //////  0 min 1.06 sec
# 0255-602-2-2-Crossmodal-PER-superficial-(-5.4 mm)-TT22.1 ////// 146/878 completed  //////  0 min 0.81 sec
# 0256-602-2-2-Crossmodal-PER-superficial-(-5.4 mm)-TT22.2 ////// 147/878 completed  //////  0 min 0.85 sec
# 0258-602-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT4.2 ////// 148/878 completed  //////  0 min 0.79 sec
# 0259-602-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT4.3 ////// 149/878 completed  //////  0 min 0.85 sec
# 0260-602-3-3-Crossmodal-PER-deep-(-5.28 mm)-TT6.1 ////// 150/878 completed  //////  0 min 0.84 sec
# 0261-602-3-3-Crossmodal-PER-deep-(-5.28 mm)-TT6.2 ////// 151/878 completed  //////  0 min 0.98 sec
# 0262-602-3-3-Crossmodal-PER-deep-(-5.28 mm)-TT6.3 ////// 152/878 completed  //////  0 min 0.89 sec
# 0263-602-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT7.1 ////// 153/878 completed  //////  0 min 0.86 sec
# 0265-602-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT7.3 ////// 154/878 completed  //////  0 min 0.78 sec
# 0266-602-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT7.4 ////// 155/878 completed  //////  0 min 0.84 sec
# 0268-602-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT7.6 ////// 156/878 completed  //////  0 min 0.73 sec
# 0271-602-3-3-Crossmodal-PER-superficial-(-4.8 mm)-TT8.3 ////// 157/878 completed  //////  0 min 0.92 sec
# 0274-602-3-3-Crossmodal-PER-deep-(-4.44 mm)-TT9.2 ////// 159/878 completed  //////  0 min 0.77 sec
# 0276-602-3-3-Crossmodal-PER-deep-(-4.44 mm)-TT9.4 ////// 160/878 completed  //////  0 min 0.84 sec
# 0277-602-3-3-Crossmodal-PER-deep-(-4.44 mm)-TT9.5 ////// 161/878 completed  //////  0 min 0.74 sec
# 0278-602-3-3-Crossmodal-PER-deep-(-4.44 mm)-TT9.6 ////// 162/878 completed  //////  0 min 0.81 sec
# 0279-602-3-3-Crossmodal-PER-superficial-(-4.68 mm)-TT10.1 ////// 163/878 completed  //////  0 min 0.80 sec
# 0281-602-3-3-Crossmodal-PER-superficial-(-4.68 mm)-TT10.3 ////// 164/878 completed  //////  0 min 0.89 sec
# 0283-602-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT11.2 ////// 165/878 completed  //////  0 min 0.80 sec
# 0284-602-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT11.3 ////// 166/878 completed  //////  0 min 0.91 sec
# 0285-602-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT11.4 ////// 167/878 completed  //////  0 min 0.85 sec
# 0286-602-3-3-Crossmodal-PER-superficial-(-4.2 mm)-TT12.1 ////// 168/878 completed  //////  0 min 0.90 sec
# 0287-602-3-3-Crossmodal-PER-superficial-(-4.2 mm)-TT12.2 ////// 169/878 completed  //////  0 min 0.81 sec
# 0291-602-3-3-Crossmodal-PER-superficial-(-4.2 mm)-TT12.6 ////// 170/878 completed  //////  0 min 0.91 sec
# 0292-602-3-3-Crossmodal-PER-superficial-(-4.2 mm)-TT12.7 ////// 171/878 completed  //////  0 min 0.77 sec
# 0293-602-3-3-Crossmodal-PER-superficial-(-4.2 mm)-TT12.8 ////// 172/878 completed  //////  0 min 0.87 sec
# 0299-602-3-3-Crossmodal-Auditory-superficial-(-5.52 mm)-TT19.5 ////// 173/878 completed  //////  0 min 0.81 sec
# 0304-602-3-3-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.4 ////// 174/878 completed  //////  0 min 0.77 sec
# 0307-602-3-3-Crossmodal-PER-superficial-(-5.4 mm)-TT22.2 ////// 175/878 completed  //////  0 min 2.79 sec
# 0308-602-3-3-Crossmodal-PER-superficial-(-5.4 mm)-TT22.3 ////// 176/878 completed  //////  0 min 0.82 sec
# 0309-602-3-3-Crossmodal-PER-superficial-(-5.4 mm)-TT22.4 ////// 177/878 completed  //////  0 min 0.84 sec
# 0311-602-4-4-Crossmodal-PER-superficial-(-5.28 mm)-TT6.1 ////// 178/878 completed  //////  0 min 0.81 sec
# 0312-602-4-4-Crossmodal-PER-superficial-(-5.28 mm)-TT6.2 ////// 179/878 completed  //////  0 min 0.79 sec
# 0313-602-4-4-Crossmodal-PER-superficial-(-5.28 mm)-TT6.3 ////// 180/878 completed  //////  0 min 0.88 sec
# 0314-602-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT7.1 ////// 181/878 completed  //////  0 min 0.86 sec
# 0315-602-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT7.2 ////// 182/878 completed  //////  0 min 0.84 sec
# 0317-602-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT7.4 ////// 183/878 completed  //////  0 min 0.94 sec
# 0318-602-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT7.5 ////// 184/878 completed  //////  0 min 0.81 sec
# 0319-602-4-4-Crossmodal-PER-superficial-(-4.8 mm)-TT8.1 ////// 185/878 completed  //////  0 min 0.90 sec
# 0320-602-4-4-Crossmodal-PER-deep-(-4.44 mm)-TT9.1 ////// 186/878 completed  //////  0 min 0.80 sec
# 0321-602-4-4-Crossmodal-PER-deep-(-4.44 mm)-TT9.2 ////// 187/878 completed  //////  0 min 0.78 sec
# 0322-602-4-4-Crossmodal-PER-deep-(-4.44 mm)-TT9.3 ////// 188/878 completed  //////  0 min 0.77 sec
# 0323-602-4-4-Crossmodal-PER-deep-(-4.44 mm)-TT9.4 ////// 189/878 completed  //////  0 min 0.85 sec
# 0324-602-4-4-Crossmodal-PER-superficial-(-4.68 mm)-TT10.1 ////// 190/878 completed  //////  0 min 0.75 sec
# 0325-602-4-4-Crossmodal-PER-superficial-(-4.68 mm)-TT10.2 ////// 191/878 completed  //////  0 min 0.82 sec
# 0326-602-4-4-Crossmodal-PER-superficial-(-4.68 mm)-TT10.3 ////// 192/878 completed  //////  0 min 0.84 sec
# 0333-602-4-4-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.3 ////// 193/878 completed  //////  0 min 0.78 sec
# 0334-602-4-4-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.4 ////// 194/878 completed  //////  0 min 0.77 sec
# 0336-602-4-4-Crossmodal-PER-superficial-(-5.4 mm)-TT22.2 ////// 195/878 completed  //////  0 min 0.74 sec
# 0338-602-5-5-Crossmodal-PER-deep-(-5.52 mm)-TT4.1 ////// 196/878 completed  //////  0 min 0.81 sec
# 0340-602-5-5-Crossmodal-PER-superficial-(-5.28 mm)-TT6.2 ////// 197/878 completed  //////  0 min 0.79 sec
# 0341-602-5-5-Crossmodal-PER-superficial-(-5.28 mm)-TT6.3 ////// 198/878 completed  //////  0 min 0.85 sec
# 0343-602-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT7.2 ////// 200/878 completed  //////  0 min 0.85 sec
# 0344-602-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT7.3 ////// 201/878 completed  //////  0 min 0.84 sec
# 0345-602-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT7.4 ////// 202/878 completed  //////  0 min 0.83 sec
# 0350-602-5-5-Crossmodal-PER-deep-(-4.44 mm)-TT9.2 ////// 204/878 completed  //////  0 min 1.03 sec
# 0351-602-5-5-Crossmodal-PER-deep-(-4.44 mm)-TT9.3 ////// 205/878 completed  //////  0 min 0.83 sec
# 0353-602-5-5-Crossmodal-PER-deep-(-4.44 mm)-TT9.5 ////// 207/878 completed  //////  0 min 0.84 sec
# 0356-602-5-5-Crossmodal-PER-superficial-(-4.68 mm)-TT10.3 ////// 208/878 completed  //////  0 min 0.72 sec
# 0357-602-5-5-Crossmodal-PER-superficial-(-4.68 mm)-TT10.4 ////// 209/878 completed  //////  0 min 0.94 sec
# 0359-602-5-5-Crossmodal-PER-superficial-(-4.2 mm)-TT12.1 ////// 210/878 completed  //////  0 min 0.87 sec
# 0362-602-5-5-Crossmodal-PER-superficial-(-4.2 mm)-TT12.4 ////// 211/878 completed  //////  0 min 0.90 sec
# 0366-602-5-5-Crossmodal-Auditory-superficial-(-5.52 mm)-TT19.2 ////// 212/878 completed  //////  0 min 0.78 sec
# 0367-602-5-5-Crossmodal-Auditory-superficial-(-5.52 mm)-TT19.3 ////// 213/878 completed  //////  0 min 0.87 sec
# 0371-602-5-5-Crossmodal-TeV-superficial-(-5.52 mm)-TT20.4 ////// 214/878 completed  //////  0 min 0.77 sec
# 0375-602-5-5-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.2 ////// 215/878 completed  //////  0 min 0.82 sec
# 0376-602-5-5-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.3 ////// 216/878 completed  //////  0 min 0.78 sec
# 0987-640-1-1-Crossmodal-PER-deep-(-6.12 mm)-TT1.1 ////// 217/878 completed  //////  0 min 0.86 sec
# 0990-640-1-1-Crossmodal-PER-deep-(-5.52 mm)-TT5.1 ////// 219/878 completed  //////  0 min 0.81 sec
# 0992-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 221/878 completed  //////  0 min 0.84 sec
# 0993-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 222/878 completed  //////  0 min 3.45 sec
# 0994-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.1 ////// 223/878 completed  //////  0 min 0.92 sec
# 0995-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.2 ////// 224/878 completed  //////  0 min 0.91 sec
# 0996-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.3 ////// 225/878 completed  //////  0 min 0.77 sec
# 0998-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.5 ////// 226/878 completed  //////  0 min 0.81 sec
# 0999-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.6 ////// 227/878 completed  //////  0 min 0.77 sec
# 1001-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.8 ////// 228/878 completed  //////  0 min 0.82 sec
# 1009-640-1-1-Crossmodal-TeV-superficial-(-5.88 mm)-TT20.2 ////// 229/878 completed  //////  0 min 0.83 sec
# 1011-640-1-1-Crossmodal-PER-deep-(-6.12 mm)-TT24.2 ////// 231/878 completed  //////  0 min 0.84 sec
# 1012-640-2-2-Crossmodal-fiber-na-(-6.12 mm)-TT3.1 ////// 232/878 completed  //////  0 min 0.84 sec
# 1013-640-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT5.1 ////// 233/878 completed  //////  0 min 0.86 sec
# 1014-640-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT5.2 ////// 234/878 completed  //////  0 min 0.76 sec
# 1017-640-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 237/878 completed  //////  0 min 0.85 sec
# 1018-640-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT10.3 ////// 238/878 completed  //////  0 min 0.79 sec
# 1019-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.1 ////// 239/878 completed  //////  0 min 0.84 sec
# 1020-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 240/878 completed  //////  0 min 0.88 sec
# 1021-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 241/878 completed  //////  0 min 0.87 sec
# 1023-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.5 ////// 243/878 completed  //////  0 min 0.96 sec
# 1024-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.6 ////// 244/878 completed  //////  0 min 0.82 sec
# 1025-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.1 ////// 245/878 completed  //////  0 min 1.02 sec
# 1026-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.2 ////// 246/878 completed  //////  0 min 0.82 sec
# 1027-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.3 ////// 247/878 completed  //////  0 min 0.89 sec
# 1028-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.4 ////// 248/878 completed  //////  0 min 0.88 sec
# 1029-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.5 ////// 249/878 completed  //////  0 min 0.96 sec
# 1033-640-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT16.1 ////// 251/878 completed  //////  0 min 0.79 sec
# 1034-640-2-2-Crossmodal-TeV-superficial-(-5.64 mm)-TT19.1 ////// 252/878 completed  //////  0 min 0.79 sec
# 1036-640-2-2-Crossmodal-TeV-deep-(-5.88 mm)-TT22.1 ////// 253/878 completed  //////  0 min 0.86 sec
# 1037-640-2-2-Crossmodal-TeV-deep-(-5.88 mm)-TT22.2 ////// 254/878 completed  //////  0 min 0.86 sec
# 1038-640-2-2-Crossmodal-TeV-deep-(-5.88 mm)-TT22.3 ////// 255/878 completed  //////  0 min 0.74 sec
# 1039-640-2-2-Crossmodal-TeV-deep-(-5.88 mm)-TT22.4 ////// 256/878 completed  //////  0 min 0.86 sec
# 1041-640-2-2-Crossmodal-TeV-superficial-(-6.24 mm)-TT23.2 ////// 257/878 completed  //////  0 min 0.76 sec
# 1042-640-2-2-Crossmodal-TeV-superficial-(-6.24 mm)-TT23.3 ////// 258/878 completed  //////  0 min 0.90 sec
# 1043-640-2-2-Crossmodal-PER-deep-(-6.12 mm)-TT24.1 ////// 259/878 completed  //////  0 min 0.74 sec
# 1044-640-2-2-Crossmodal-PER-deep-(-6.12 mm)-TT24.2 ////// 260/878 completed  //////  0 min 0.85 sec
# 1045-640-2-2-Crossmodal-PER-deep-(-6.12 mm)-TT24.3 ////// 261/878 completed  //////  0 min 0.78 sec
# 1047-640-3-3-Crossmodal-iHPC-na-(-5.64 mm)-TT4.1 ////// 262/878 completed  //////  0 min 1.00 sec
# 1050-640-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT5.1 ////// 264/878 completed  //////  0 min 0.93 sec
# 1051-640-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT10.1 ////// 265/878 completed  //////  0 min 0.92 sec
# 1052-640-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 266/878 completed  //////  0 min 0.82 sec
# 1056-640-3-3-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 270/878 completed  //////  0 min 1.07 sec
# 1057-640-3-3-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 271/878 completed  //////  0 min 0.86 sec
# 1058-640-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT13.1 ////// 272/878 completed  //////  0 min 0.95 sec
# 1059-640-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT13.2 ////// 273/878 completed  //////  0 min 0.86 sec
# 1062-640-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT15.2 ////// 275/878 completed  //////  0 min 0.86 sec
# 1063-640-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT15.3 ////// 276/878 completed  //////  0 min 0.80 sec
# 1067-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.1 ////// 277/878 completed  //////  0 min 0.82 sec
# 1068-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.2 ////// 278/878 completed  //////  0 min 0.74 sec
# 1069-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.3 ////// 279/878 completed  //////  0 min 1.00 sec
# 1070-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.4 ////// 280/878 completed  //////  0 min 0.80 sec
# 1071-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.5 ////// 281/878 completed  //////  0 min 0.78 sec
# 1072-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.6 ////// 282/878 completed  //////  0 min 0.80 sec
# 1073-640-3-3-Crossmodal-PER-deep-(-6.12 mm)-TT24.1 ////// 283/878 completed  //////  0 min 0.86 sec
# 1074-640-3-3-Crossmodal-PER-deep-(-6.12 mm)-TT24.2 ////// 284/878 completed  //////  0 min 4.30 sec
# 1075-640-4-4-Crossmodal-fiber-na-(-6.12 mm)-TT3.1 ////// 285/878 completed  //////  0 min 1.52 sec
# 1076-640-4-4-Crossmodal-fiber-na-(-6.12 mm)-TT3.2 ////// 286/878 completed  //////  0 min 0.93 sec
# 1078-640-4-4-Crossmodal-iHPC-na-(-5.64 mm)-TT4.1 ////// 288/878 completed  //////  0 min 0.93 sec
# 1080-640-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT10.1 ////// 290/878 completed  //////  0 min 0.99 sec
# 1081-640-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 291/878 completed  //////  0 min 0.86 sec
# 1082-640-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT10.3 ////// 292/878 completed  //////  0 min 0.96 sec
# 1084-640-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT10.5 ////// 293/878 completed  //////  0 min 0.85 sec
# 1085-640-4-4-Crossmodal-PER-deep-(-4.56 mm)-TT11.1 ////// 294/878 completed  //////  0 min 0.83 sec
# 1089-640-4-4-Crossmodal-TeV-superficial-(-5.88 mm)-TT20.1 ////// 295/878 completed  //////  0 min 0.86 sec
# 1091-640-4-4-Crossmodal-TeV-deep-(-5.88 mm)-TT22.1 ////// 296/878 completed  //////  0 min 0.81 sec
# 1092-640-4-4-Crossmodal-TeV-deep-(-5.88 mm)-TT22.2 ////// 297/878 completed  //////  0 min 0.80 sec
# 1094-640-4-4-Crossmodal-TeV-deep-(-5.88 mm)-TT22.4 ////// 298/878 completed  //////  0 min 0.75 sec
# 1095-640-4-4-Crossmodal-TeV-deep-(-5.88 mm)-TT22.5 ////// 299/878 completed  //////  0 min 0.81 sec
# 1096-640-4-4-Crossmodal-TeV-deep-(-5.88 mm)-TT22.6 ////// 300/878 completed  //////  0 min 0.86 sec
# 1103-640-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 302/878 completed  //////  0 min 0.86 sec
# 1106-640-5-5-Crossmodal-PER-superficial-(-4.56 mm)-TT15.1 ////// 304/878 completed  //////  0 min 0.80 sec
# 1108-640-5-5-Crossmodal-PER-superficial-(-5.64 mm)-TT19.1 ////// 305/878 completed  //////  0 min 0.86 sec
# 1115-640-5-5-Crossmodal-TeV-deep-(-5.88 mm)-TT22.2 ////// 306/878 completed  //////  0 min 0.96 sec
# 1116-640-5-5-Crossmodal-TeV-deep-(-5.88 mm)-TT22.3 ////// 307/878 completed  //////  0 min 0.88 sec
# 1117-640-5-5-Crossmodal-TeV-deep-(-5.88 mm)-TT22.4 ////// 308/878 completed  //////  0 min 0.85 sec
# 1118-640-5-5-Crossmodal-TeV-deep-(-5.88 mm)-TT22.5 ////// 309/878 completed  //////  0 min 0.82 sec
# 1119-640-5-5-Crossmodal-PER-deep-(-6.12 mm)-TT24.1 ////// 310/878 completed  //////  0 min 0.80 sec
# 1324-647-4-4-Crossmodal-PER-deep-(-6 mm)-TT5.1 ////// 311/878 completed  //////  0 min 0.81 sec
# 1325-647-4-4-Crossmodal-PER-deep-(-6 mm)-TT5.2 ////// 312/878 completed  //////  0 min 0.82 sec
# 1327-647-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT11.1 ////// 313/878 completed  //////  0 min 0.85 sec
# 1328-647-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT12.1 ////// 314/878 completed  //////  0 min 0.81 sec
# 1329-647-4-4-Crossmodal-PER-superficial-(-5.4 mm)-TT13.1 ////// 315/878 completed  //////  0 min 0.86 sec
# 1330-647-4-4-Crossmodal-PER-deep-(-5.2 mm)-TT15.1 ////// 316/878 completed  //////  0 min 0.83 sec
# 1333-647-4-4-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.1 ////// 317/878 completed  //////  0 min 0.83 sec
# 1334-647-4-4-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.2 ////// 318/878 completed  //////  0 min 0.78 sec
# 1336-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.2 ////// 320/878 completed  //////  0 min 0.94 sec
# 1337-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.3 ////// 321/878 completed  //////  0 min 0.80 sec
# 1338-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.4 ////// 322/878 completed  //////  0 min 0.86 sec
# 1339-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.5 ////// 323/878 completed  //////  0 min 0.80 sec
# 1340-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.6 ////// 324/878 completed  //////  0 min 1.07 sec
# 1341-647-4-4-Crossmodal-PER-superficial-(-5.88 mm)-TT19.1 ////// 325/878 completed  //////  0 min 0.86 sec
# 1343-647-4-4-Crossmodal-PER-superficial-(-5.88 mm)-TT19.3 ////// 326/878 completed  //////  0 min 1.02 sec
# 1345-647-4-4-Crossmodal-PER-superficial-(-5.88 mm)-TT19.5 ////// 327/878 completed  //////  0 min 1.04 sec
# 1346-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 328/878 completed  //////  0 min 0.80 sec
# 1347-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 329/878 completed  //////  0 min 0.76 sec
# 1348-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 330/878 completed  //////  0 min 0.78 sec
# 1349-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 331/878 completed  //////  0 min 0.79 sec
# 1350-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.5 ////// 332/878 completed  //////  0 min 0.86 sec
# 1351-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.6 ////// 333/878 completed  //////  0 min 0.81 sec
# 1352-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.7 ////// 334/878 completed  //////  0 min 0.83 sec
# 1356-647-5-5-Crossmodal-PER-deep-(-5.76 mm)-TT7.1 ////// 337/878 completed  //////  0 min 0.86 sec
# 1357-647-5-5-Crossmodal-PER-deep-(-5.76 mm)-TT7.2 ////// 338/878 completed  //////  0 min 0.81 sec
# 1358-647-5-5-Crossmodal-PER-deep-(-5.4 mm)-TT9.1 ////// 339/878 completed  //////  0 min 0.86 sec
# 1359-647-5-5-Crossmodal-PER-deep-(-5.4 mm)-TT9.2 ////// 340/878 completed  //////  0 min 0.84 sec
# 1361-647-5-5-Crossmodal-PER-superficial-(-5.28 mm)-TT11.2 ////// 341/878 completed  //////  0 min 0.87 sec
# 1362-647-5-5-Crossmodal-PER-superficial-(-5.4 mm)-TT13.1 ////// 342/878 completed  //////  0 min 0.83 sec
# 1363-647-5-5-Crossmodal-PER-deep-(-5.2 mm)-TT15.1 ////// 343/878 completed  //////  0 min 0.84 sec
# 1366-647-5-5-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.1 ////// 344/878 completed  //////  0 min 0.90 sec
# 1367-647-5-5-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.2 ////// 345/878 completed  //////  0 min 0.96 sec
# 1370-647-5-5-Crossmodal-PER-superficial-(-5.64 mm)-TT17.3 ////// 346/878 completed  //////  0 min 0.87 sec
# 1371-647-5-5-Crossmodal-PER-deep-(-5.76 mm)-TT18.1 ////// 347/878 completed  //////  0 min 0.93 sec
# 1372-647-5-5-Crossmodal-PER-superficial-(-5.88 mm)-TT19.1 ////// 348/878 completed  //////  0 min 0.77 sec
# 1374-647-5-5-Crossmodal-PER-superficial-(-5.88 mm)-TT19.3 ////// 349/878 completed  //////  0 min 1.02 sec
# 1377-647-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 350/878 completed  //////  0 min 0.78 sec
# 1378-647-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 351/878 completed  //////  0 min 0.86 sec
# 1379-647-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 352/878 completed  //////  0 min 0.77 sec
# 1380-647-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 353/878 completed  //////  0 min 0.89 sec
# 1382-647-6-6-Crossmodal-PER-deep-(-5.76 mm)-TT7.1 ////// 354/878 completed  //////  0 min 4.73 sec
# 1383-647-6-6-Crossmodal-PER-deep-(-5.4 mm)-TT9.1 ////// 355/878 completed  //////  0 min 0.75 sec
# 1385-647-6-6-Crossmodal-PER-deep-(-5.4 mm)-TT9.3 ////// 356/878 completed  //////  0 min 0.92 sec
# 1391-647-6-6-Crossmodal-PER-deep-(-5.2 mm)-TT15.4 ////// 357/878 completed  //////  0 min 0.93 sec
# 1392-647-6-6-Crossmodal-PER-deep-(-5.2 mm)-TT15.5 ////// 358/878 completed  //////  0 min 0.98 sec
# 1394-647-6-6-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.2 ////// 360/878 completed  //////  0 min 0.87 sec
# 1395-647-6-6-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.3 ////// 361/878 completed  //////  0 min 0.91 sec
# 1396-647-6-6-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.4 ////// 362/878 completed  //////  0 min 1.03 sec
# 1399-647-6-6-Crossmodal-PER-superficial-(-5.88 mm)-TT19.1 ////// 363/878 completed  //////  0 min 0.81 sec
# 1401-647-6-6-Crossmodal-PER-superficial-(-5.88 mm)-TT19.3 ////// 364/878 completed  //////  0 min 0.97 sec
# 1404-647-6-6-Crossmodal-PER-superficial-(-6.24 mm)-TT20.3 ////// 365/878 completed  //////  0 min 0.88 sec
# 1406-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 366/878 completed  //////  0 min 1.01 sec
# 1407-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 367/878 completed  //////  0 min 0.76 sec
# 1408-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 368/878 completed  //////  0 min 0.80 sec
# 1409-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.5 ////// 369/878 completed  //////  0 min 0.79 sec
# 1410-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.6 ////// 370/878 completed  //////  0 min 0.87 sec
# 1411-647-7-7-Crossmodal-PER-superficial-(-5.28 mm)-TT11.1 ////// 371/878 completed  //////  0 min 0.82 sec
# 1413-647-7-7-Crossmodal-PER-deep-(-5.2 mm)-TT15.2 ////// 372/878 completed  //////  0 min 0.91 sec
# 1414-647-7-7-Crossmodal-PER-deep-(-5.2 mm)-TT15.3 ////// 373/878 completed  //////  0 min 2.71 sec
# 1417-647-7-7-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.1 ////// 374/878 completed  //////  0 min 0.88 sec
# 1421-647-7-7-Crossmodal-PER-superficial-(-5.88 mm)-TT19.2 ////// 375/878 completed  //////  0 min 0.74 sec
# 1423-647-7-7-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 376/878 completed  //////  0 min 1.03 sec
# 1425-647-7-7-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 377/878 completed  //////  0 min 0.78 sec
# 1527-654-1-1-Crossmodal-Visual-superficial-(-6.6 mm)-TT1.4 ////// 379/878 completed  //////  0 min 0.98 sec
# 1530-654-1-1-Crossmodal-Visual-deep-(-5.64 mm)-TT6.1 ////// 381/878 completed  //////  0 min 0.84 sec
# 1533-654-1-1-Crossmodal-PER-deep-(-5.4 mm)-TT10.1 ////// 384/878 completed  //////  0 min 0.96 sec
# 1534-654-1-1-Crossmodal-PER-deep-(-5.4 mm)-TT10.2 ////// 385/878 completed  //////  0 min 0.78 sec
# 1535-654-1-1-Crossmodal-PER-deep-(-5.4 mm)-TT10.3 ////// 386/878 completed  //////  0 min 0.77 sec
# 1536-654-1-1-Crossmodal-PER-deep-(-5.4 mm)-TT10.4 ////// 387/878 completed  //////  0 min 0.74 sec
# 1537-654-1-1-Crossmodal-PER-deep-(-5.52 mm)-TT11.1 ////// 388/878 completed  //////  0 min 0.88 sec
# 1539-654-1-1-Crossmodal-PER-deep-(-5.52 mm)-TT11.3 ////// 389/878 completed  //////  0 min 0.73 sec
# 1541-654-1-1-Crossmodal-PER-deep-(-5.52 mm)-TT11.5 ////// 390/878 completed  //////  0 min 0.80 sec
# 1543-654-1-1-Crossmodal-Auditory-deep-(-4.8 mm)-TT12.1 ////// 391/878 completed  //////  0 min 0.75 sec
# 1544-654-1-1-Crossmodal-Auditory-deep-(-4.8 mm)-TT12.2 ////// 392/878 completed  //////  0 min 0.93 sec
# 1548-654-1-1-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.1 ////// 393/878 completed  //////  0 min 1.06 sec
# 1549-654-1-1-Crossmodal-Auditory-deep-(-5.2 mm)-TT16.1 ////// 394/878 completed  //////  0 min 0.85 sec
# 1550-654-1-1-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.1 ////// 395/878 completed  //////  0 min 0.84 sec
# 1551-654-1-1-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.2 ////// 396/878 completed  //////  0 min 0.92 sec
# 1552-654-1-1-Crossmodal-Auditory-superficial-(-6.12 mm)-TT20.1 ////// 397/878 completed  //////  0 min 0.83 sec
# 1553-654-1-1-Crossmodal-Auditory-superficial-(-6.12 mm)-TT20.2 ////// 398/878 completed  //////  0 min 1.00 sec
# 1554-654-1-1-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 399/878 completed  //////  0 min 0.95 sec
# 1555-654-1-1-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 400/878 completed  //////  0 min 0.95 sec
# 1556-654-1-1-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 401/878 completed  //////  0 min 0.94 sec
# 1557-654-1-1-Crossmodal-Auditory-superficial-(-6.6 mm)-TT23.1 ////// 402/878 completed  //////  0 min 0.80 sec
# 1558-654-1-1-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 403/878 completed  //////  0 min 0.82 sec
# 1560-654-1-1-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.3 ////// 404/878 completed  //////  0 min 0.79 sec
# 1561-654-1-1-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.4 ////// 405/878 completed  //////  0 min 0.85 sec
# 1567-654-2-2-Crossmodal-Visual-superficial-(-6.48 mm)-TT3.1 ////// 406/878 completed  //////  0 min 0.77 sec
# 1574-654-2-2-Crossmodal-PER-deep-(-5.4 mm)-TT10.3 ////// 412/878 completed  //////  0 min 0.87 sec
# 1576-654-2-2-Crossmodal-PER-deep-(-5.4 mm)-TT10.5 ////// 413/878 completed  //////  0 min 0.81 sec
# 1579-654-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT13.2 ////// 414/878 completed  //////  0 min 0.82 sec
# 1585-654-2-2-Crossmodal-Auditory-deep-(-5.88 mm)-TT18.1 ////// 418/878 completed  //////  0 min 0.78 sec
# 1587-654-2-2-Crossmodal-Auditory-superficial-(-6.12 mm)-TT20.2 ////// 419/878 completed  //////  0 min 0.90 sec
# 1589-654-2-2-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 421/878 completed  //////  0 min 0.96 sec
# 1590-654-2-2-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 422/878 completed  //////  0 min 0.82 sec
# 1591-654-2-2-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 423/878 completed  //////  0 min 0.81 sec
# 1592-654-2-2-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 424/878 completed  //////  0 min 0.83 sec
# 1593-654-2-2-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 425/878 completed  //////  0 min 0.87 sec
# 1595-654-2-2-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.3 ////// 426/878 completed  //////  0 min 0.95 sec
# 1599-654-3-3-Crossmodal-Visual-superficial-(-6.6 mm)-TT1.4 ////// 429/878 completed  //////  0 min 0.79 sec
# 1600-654-3-3-Crossmodal-Visual-superficial-(-6.6 mm)-TT1.5 ////// 430/878 completed  //////  0 min 1.02 sec
# 1601-654-3-3-Crossmodal-Visual-deep-(-6.36 mm)-TT2.1 ////// 431/878 completed  //////  0 min 1.01 sec
# 1602-654-3-3-Crossmodal-Visual-deep-(-6.48 mm)-TT3.1 ////// 432/878 completed  //////  0 min 0.80 sec
# 1603-654-3-3-Crossmodal-Visual-deep-(-6.24 mm)-TT4.1 ////// 433/878 completed  //////  0 min 0.76 sec
# 1605-654-3-3-Crossmodal-Visual-deep-(-5.64 mm)-TT6.2 ////// 435/878 completed  //////  0 min 0.86 sec
# 1606-654-3-3-Crossmodal-Visual-deep-(-5.64 mm)-TT6.3 ////// 436/878 completed  //////  0 min 0.84 sec
# 1610-654-3-3-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.2 ////// 439/878 completed  //////  0 min 0.87 sec
# 1611-654-3-3-Crossmodal-Tev-deep-(-5.88 mm)-TT18.1 ////// 440/878 completed  //////  0 min 0.87 sec
# 1612-654-3-3-Crossmodal-Tev-deep-(-5.88 mm)-TT18.2 ////// 441/878 completed  //////  0 min 0.83 sec
# 1613-654-3-3-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.1 ////// 442/878 completed  //////  0 min 0.82 sec
# 1614-654-3-3-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.2 ////// 443/878 completed  //////  0 min 0.86 sec
# 1615-654-3-3-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.3 ////// 444/878 completed  //////  0 min 0.85 sec
# 1616-654-3-3-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 445/878 completed  //////  0 min 0.83 sec
# 1617-654-3-3-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 446/878 completed  //////  0 min 0.81 sec
# 1619-654-3-3-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 447/878 completed  //////  0 min 0.86 sec
# 1621-654-3-3-Crossmodal-Tev-superficial-(-6.6 mm)-TT23.2 ////// 448/878 completed  //////  0 min 0.80 sec
# 1622-654-3-3-Crossmodal-Tev-superficial-(-6.6 mm)-TT23.3 ////// 449/878 completed  //////  0 min 0.84 sec
# 1623-654-3-3-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 450/878 completed  //////  0 min 6.18 sec
# 1624-654-3-3-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.2 ////// 451/878 completed  //////  0 min 0.84 sec
# 1625-654-3-3-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.3 ////// 452/878 completed  //////  0 min 0.88 sec
# 1626-654-3-3-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.4 ////// 453/878 completed  //////  0 min 0.76 sec
# 1646-654-5-5-Crossmodal-PER-superficial-(-5.52 mm)-TT11.1 ////// 456/878 completed  //////  0 min 0.84 sec
# 1651-654-5-5-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.1 ////// 458/878 completed  //////  0 min 0.82 sec
# 1653-654-5-5-Crossmodal-Auditory-deep-(-5.2 mm)-TT16.2 ////// 460/878 completed  //////  0 min 0.85 sec
# 1654-654-5-5-Crossmodal-Auditory-deep-(-5.2 mm)-TT16.3 ////// 461/878 completed  //////  0 min 0.84 sec
# 1655-654-5-5-Crossmodal-Tev-deep-(-5.88 mm)-TT18.1 ////// 462/878 completed  //////  0 min 0.82 sec
# 1656-654-5-5-Crossmodal-Tev-deep-(-5.88 mm)-TT18.2 ////// 463/878 completed  //////  0 min 0.78 sec
# 1657-654-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 464/878 completed  //////  0 min 0.96 sec
# 1659-654-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 465/878 completed  //////  0 min 0.85 sec
# 1660-654-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 466/878 completed  //////  0 min 0.91 sec
# 1661-654-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.5 ////// 467/878 completed  //////  0 min 0.81 sec
# 1662-654-5-5-Crossmodal-Tev-superficial-(-6.6 mm)-TT23.1 ////// 468/878 completed  //////  0 min 0.94 sec
# 1663-654-5-5-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 469/878 completed  //////  0 min 0.92 sec
# 1664-654-5-5-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.2 ////// 470/878 completed  //////  0 min 0.83 sec
# 1667-654-5-5-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.5 ////// 471/878 completed  //////  0 min 0.82 sec
# 1670-654-6-6-Crossmodal-Auditory-deep-(-4.8 mm)-TT12.1 ////// 473/878 completed  //////  0 min 0.88 sec
# 1673-654-6-6-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.1 ////// 474/878 completed  //////  0 min 0.86 sec
# 1674-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.1 ////// 475/878 completed  //////  0 min 0.79 sec
# 1675-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.2 ////// 476/878 completed  //////  0 min 0.76 sec
# 1676-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.3 ////// 477/878 completed  //////  0 min 0.80 sec
# 1677-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT21.1 ////// 478/878 completed  //////  0 min 0.86 sec
# 1679-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT21.3 ////// 479/878 completed  //////  0 min 0.85 sec
# 1683-654-6-6-Crossmodal-Tev-superficial-(-6.6 mm)-TT23.1 ////// 480/878 completed  //////  0 min 0.72 sec
# 1684-654-6-6-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 481/878 completed  //////  0 min 0.85 sec
# 1685-654-6-6-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.2 ////// 482/878 completed  //////  0 min 0.81 sec
# 1686-654-6-6-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.3 ////// 483/878 completed  //////  0 min 0.85 sec
# 1769-679-1-1-Crossmodal-Visual-deep-(-6.36 mm)-TT1.1 ////// 484/878 completed  //////  0 min 0.76 sec
# 1770-679-1-1-Crossmodal-Visual-deep-(-6.36 mm)-TT1.2 ////// 485/878 completed  //////  0 min 0.82 sec
# 1771-679-1-1-Crossmodal-Visual-deep-(-6.24 mm)-TT2.1 ////// 486/878 completed  //////  0 min 0.94 sec
# 1772-679-1-1-Crossmodal-Visual-deep-(-6.24 mm)-TT2.2 ////// 487/878 completed  //////  0 min 0.88 sec
# 1773-679-1-1-Crossmodal-Visual-deep-(-6.24 mm)-TT2.3 ////// 488/878 completed  //////  0 min 0.99 sec
# 1776-679-1-1-Crossmodal-Tev-deep-(-4.68 mm)-TT10.1 ////// 490/878 completed  //////  0 min 0.96 sec
# 1777-679-1-1-Crossmodal-Tev-deep-(-4.68 mm)-TT10.2 ////// 491/878 completed  //////  0 min 0.93 sec
# 1778-679-1-1-Crossmodal-Tev-deep-(-4.68 mm)-TT10.3 ////// 492/878 completed  //////  0 min 0.80 sec
# 1781-679-1-1-Crossmodal-Visual-deep-(-4.56 mm)-TT13.2 ////// 494/878 completed  //////  0 min 0.87 sec
# 1782-679-1-1-Crossmodal-Visual-deep-(-4.56 mm)-TT13.3 ////// 495/878 completed  //////  0 min 0.80 sec
# 1783-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.1 ////// 496/878 completed  //////  0 min 0.82 sec
# 1784-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.2 ////// 497/878 completed  //////  0 min 0.80 sec
# 1785-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.3 ////// 498/878 completed  //////  0 min 0.83 sec
# 1787-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.5 ////// 500/878 completed  //////  0 min 0.84 sec
# 1789-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.7 ////// 502/878 completed  //////  0 min 1.18 sec
# 1793-679-1-1-Crossmodal-Visual-deep-(-4.68 mm)-TT15.3 ////// 505/878 completed  //////  0 min 1.18 sec
# 1794-679-1-1-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.1 ////// 506/878 completed  //////  0 min 1.68 sec
# 1795-679-1-1-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.2 ////// 507/878 completed  //////  0 min 0.83 sec
# 1796-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.1 ////// 508/878 completed  //////  0 min 0.82 sec
# 1797-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.2 ////// 509/878 completed  //////  0 min 0.89 sec
# 1798-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.3 ////// 510/878 completed  //////  0 min 0.98 sec
# 1799-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.4 ////// 511/878 completed  //////  0 min 0.84 sec
# 1800-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.5 ////// 512/878 completed  //////  0 min 0.90 sec
# 1802-679-1-1-Crossmodal-Auditory-deep-(-5.52 mm)-TT20.1 ////// 513/878 completed  //////  0 min 0.80 sec
# 1803-679-1-1-Crossmodal-Auditory-deep-(-5.64 mm)-TT21.1 ////// 514/878 completed  //////  0 min 0.88 sec
# 1806-679-1-1-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.2 ////// 516/878 completed  //////  0 min 0.85 sec
# 1807-679-1-1-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.3 ////// 517/878 completed  //////  0 min 0.79 sec
# 1808-679-1-1-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.4 ////// 518/878 completed  //////  0 min 0.79 sec
# 1810-679-1-1-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.6 ////// 519/878 completed  //////  0 min 0.89 sec
# 1811-679-1-1-Crossmodal-Visual-superficial-(-6.24 mm)-TT23.1 ////// 520/878 completed  //////  0 min 0.78 sec
# 1812-679-2-2-Crossmodal-Visual-deep-(-6.36 mm)-TT1.1 ////// 521/878 completed  //////  0 min 0.84 sec
# 1813-679-2-2-Crossmodal-Visual-deep-(-6.36 mm)-TT1.2 ////// 522/878 completed  //////  0 min 0.77 sec
# 1814-679-2-2-Crossmodal-Visual-deep-(-6.36 mm)-TT1.3 ////// 523/878 completed  //////  0 min 0.90 sec
# 1815-679-2-2-Crossmodal-Visual-deep-(-6.24 mm)-TT2.1 ////// 524/878 completed  //////  0 min 0.81 sec
# 1817-679-2-2-Crossmodal-Visual-deep-(-6.24 mm)-TT2.3 ////// 526/878 completed  //////  0 min 0.84 sec
# 1819-679-2-2-Crossmodal-Visual-deep-(-4.56 mm)-TT11.1 ////// 528/878 completed  //////  0 min 0.85 sec
# 1820-679-2-2-Crossmodal-Visual-deep-(-4.56 mm)-TT11.2 ////// 529/878 completed  //////  0 min 0.80 sec
# 1822-679-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT12.2 ////// 530/878 completed  //////  0 min 0.85 sec
# 1823-679-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT12.3 ////// 531/878 completed  //////  0 min 0.92 sec
# 1824-679-2-2-Crossmodal-Visual-deep-(-4.56 mm)-TT13.1 ////// 532/878 completed  //////  0 min 0.88 sec
# 1825-679-2-2-Crossmodal-Visual-deep-(-4.56 mm)-TT13.2 ////// 533/878 completed  //////  0 min 0.95 sec
# ...
# 2207-699-1-1-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 702/878 completed  //////  0 min 0.86 sec
# 2208-699-1-1-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.4 ////// 703/878 completed  //////  0 min 0.86 sec
# 2209-699-1-1-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.1 ////// 704/878 completed  //////  0 min 0.83 sec
# 2210-699-1-1-Crossmodal-Tev-deep-(-4.92 mm)-TT16.1 ////// 705/878 completed  //////  0 min 0.95 sec
# 2212-699-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT17.1 ////// 707/878 completed  //////  0 min 0.90 sec
# 2213-699-1-1-Crossmodal-Tev-deep-(-5.64 mm)-TT18.1 ////// 708/878 completed  //////  0 min 0.84 sec
# 2214-699-1-1-Crossmodal-Tev-deep-(-5.64 mm)-TT18.2 ////// 709/878 completed  //////  0 min 0.76 sec
# 2215-699-1-1-Crossmodal-Tev-deep-(-5.64 mm)-TT18.3 ////// 710/878 completed  //////  0 min 0.81 sec
# 2216-699-1-1-Crossmodal-Tev-deep-(-5.76 mm)-TT20.1 ////// 711/878 completed  //////  0 min 0.84 sec
# 2217-699-1-1-Crossmodal-Tev-deep-(-5.76 mm)-TT20.2 ////// 712/878 completed  //////  0 min 0.77 sec
# 2219-699-1-1-Crossmodal-Visual-deep-(-6.48 mm)-TT24.1 ////// 714/878 completed  //////  0 min 1.03 sec
# 2221-699-2-2-Crossmodal-PER-deep-(-5.76 mm)-TT5.1 ////// 716/878 completed  //////  0 min 0.93 sec
# 2222-699-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT7.1 ////// 717/878 completed  //////  0 min 0.89 sec
# 2223-699-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT7.2 ////// 718/878 completed  //////  0 min 0.98 sec
# 2226-699-2-2-Crossmodal-Tev-deep-(-4.8 mm)-TT10.1 ////// 720/878 completed  //////  0 min 0.92 sec
# 2227-699-2-2-Crossmodal-PER-deep-(-4.68 mm)-TT11.1 ////// 721/878 completed  //////  0 min 0.94 sec
# 2228-699-2-2-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.1 ////// 722/878 completed  //////  0 min 0.74 sec
# 2232-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 725/878 completed  //////  0 min 0.88 sec
# 2234-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.4 ////// 727/878 completed  //////  0 min 0.74 sec
# 2235-699-2-2-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.1 ////// 728/878 completed  //////  0 min 0.89 sec
# 2236-699-2-2-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 729/878 completed  //////  0 min 0.80 sec
# 2237-699-2-2-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 730/878 completed  //////  0 min 0.90 sec
# 2239-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.2 ////// 732/878 completed  //////  0 min 0.80 sec
# 2240-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.3 ////// 733/878 completed  //////  0 min 0.93 sec
# 2241-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.4 ////// 734/878 completed  //////  0 min 0.80 sec
# 2242-699-2-2-Crossmodal-Tev-deep-(-4.92 mm)-TT16.1 ////// 735/878 completed  //////  0 min 0.80 sec
# 2243-699-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT17.1 ////// 736/878 completed  //////  0 min 0.83 sec
# 2244-699-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT17.2 ////// 737/878 completed  //////  0 min 0.88 sec
# 2245-699-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT17.3 ////// 738/878 completed  //////  0 min 0.81 sec
# 2246-699-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT17.4 ////// 739/878 completed  //////  0 min 0.91 sec
# 2247-699-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT17.5 ////// 740/878 completed  //////  0 min 1.00 sec
# 2249-699-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT17.7 ////// 741/878 completed  //////  0 min 9.09 sec
# 2250-699-2-2-Crossmodal-Tev-deep-(-5.64 mm)-TT18.1 ////// 742/878 completed  //////  0 min 0.79 sec
# 2251-699-2-2-Crossmodal-Tev-deep-(-5.64 mm)-TT18.2 ////// 743/878 completed  //////  0 min 0.97 sec
# 2253-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.1 ////// 744/878 completed  //////  0 min 0.90 sec
# 2254-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.2 ////// 745/878 completed  //////  0 min 0.82 sec
# 2255-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.3 ////// 746/878 completed  //////  0 min 0.82 sec
# 2257-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.5 ////// 748/878 completed  //////  0 min 0.81 sec
# 2258-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.6 ////// 749/878 completed  //////  0 min 1.03 sec
# 2259-699-3-3-Crossmodal-Visual-deep-(-6.96 mm)-TT1.1 ////// 750/878 completed  //////  0 min 0.88 sec
# 2260-699-3-3-Crossmodal-PER-deep-(-5.76 mm)-TT5.1 ////// 751/878 completed  //////  0 min 0.89 sec
# 2261-699-3-3-Crossmodal-PER-deep-(-5.76 mm)-TT5.2 ////// 752/878 completed  //////  0 min 0.89 sec
# 2262-699-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT7.1 ////// 753/878 completed  //////  0 min 0.90 sec
# 2263-699-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT7.2 ////// 754/878 completed  //////  0 min 0.74 sec
# 2265-699-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT7.4 ////// 755/878 completed  //////  0 min 0.80 sec
# 2267-699-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT8.2 ////// 757/878 completed  //////  0 min 0.82 sec
# 2268-699-3-3-Crossmodal-PER-deep-(-5.2 mm)-TT9.1 ////// 758/878 completed  //////  0 min 0.86 sec
# 2269-699-3-3-Crossmodal-PER-deep-(-5.2 mm)-TT9.2 ////// 759/878 completed  //////  0 min 0.86 sec
# 2270-699-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT10.1 ////// 760/878 completed  //////  0 min 0.77 sec
# 2271-699-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 761/878 completed  //////  0 min 0.79 sec
# 2272-699-3-3-Crossmodal-PER-deep-(-4.68 mm)-TT11.1 ////// 762/878 completed  //////  0 min 0.86 sec
# 2273-699-3-3-Crossmodal-PER-deep-(-4.68 mm)-TT11.2 ////// 763/878 completed  //////  0 min 0.85 sec
# 2276-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.3 ////// 765/878 completed  //////  0 min 0.87 sec
# 2277-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.4 ////// 766/878 completed  //////  0 min 0.92 sec
# 2279-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.1 ////// 767/878 completed  //////  0 min 0.87 sec
# 2280-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 768/878 completed  //////  0 min 0.80 sec
# 2281-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.1 ////// 769/878 completed  //////  0 min 1.00 sec
# 2282-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 770/878 completed  //////  0 min 1.32 sec
# 2283-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 771/878 completed  //////  0 min 2.14 sec
# 2285-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.2 ////// 773/878 completed  //////  0 min 0.85 sec
# 2286-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.3 ////// 774/878 completed  //////  0 min 0.79 sec
# 2287-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.4 ////// 775/878 completed  //////  0 min 0.96 sec
# 2288-699-3-3-Crossmodal-PER-deep-(-4.92 mm)-TT16.1 ////// 776/878 completed  //////  0 min 0.86 sec
# 2289-699-3-3-Crossmodal-PER-deep-(-4.92 mm)-TT16.2 ////// 777/878 completed  //////  0 min 0.82 sec
# 2290-699-3-3-Crossmodal-PER-deep-(-5.28 mm)-TT17.1 ////// 778/878 completed  //////  0 min 0.98 sec
# 2291-699-3-3-Crossmodal-PER-deep-(-5.28 mm)-TT17.2 ////// 779/878 completed  //////  0 min 0.97 sec
# 2292-699-3-3-Crossmodal-PER-deep-(-5.28 mm)-TT17.3 ////// 780/878 completed  //////  0 min 0.83 sec
# 2293-699-3-3-Crossmodal-PER-deep-(-5.28 mm)-TT17.4 ////// 781/878 completed  //////  0 min 0.80 sec
# 2294-699-3-3-Crossmodal-Tev-deep-(-5.64 mm)-TT18.1 ////// 782/878 completed  //////  0 min 1.01 sec
# 2295-699-3-3-Crossmodal-Tev-deep-(-5.64 mm)-TT18.2 ////// 783/878 completed  //////  0 min 1.02 sec
# 2296-699-3-3-Crossmodal-Tev-deep-(-5.64 mm)-TT18.3 ////// 784/878 completed  //////  0 min 0.95 sec
# 2297-699-3-3-Crossmodal-Tev-deep-(-5.64 mm)-TT18.4 ////// 785/878 completed  //////  0 min 0.85 sec
# 2298-699-3-3-Crossmodal-Tev-deep-(-5.64 mm)-TT18.5 ////// 786/878 completed  //////  0 min 1.03 sec
# 2299-699-3-3-Crossmodal-Tev-superficial-(-5.76 mm)-TT20.1 ////// 787/878 completed  //////  0 min 0.97 sec
# 2300-699-3-3-Crossmodal-Visual-superficial-(-6.36 mm)-TT23.1 ////// 788/878 completed  //////  0 min 0.91 sec
# 2305-699-4-4-Crossmodal-PER-deep-(-5.52 mm)-TT8.1 ////// 791/878 completed  //////  0 min 1.09 sec
# 2306-699-4-4-Crossmodal-PER-deep-(-5.52 mm)-TT8.2 ////// 792/878 completed  //////  0 min 1.04 sec
# 2307-699-4-4-Crossmodal-PER-deep-(-5.52 mm)-TT8.3 ////// 793/878 completed  //////  0 min 0.77 sec
# 2309-699-4-4-Crossmodal-PER-deep-(-5.2 mm)-TT9.1 ////// 794/878 completed  //////  0 min 0.92 sec
# 2310-699-4-4-Crossmodal-PER-deep-(-5.2 mm)-TT9.2 ////// 795/878 completed  //////  0 min 0.77 sec
# 2311-699-4-4-Crossmodal-PER-deep-(-5.2 mm)-TT9.3 ////// 796/878 completed  //////  0 min 0.93 sec
# 2312-699-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT10.1 ////// 797/878 completed  //////  0 min 0.77 sec
# 2313-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.1 ////// 798/878 completed  //////  0 min 0.94 sec
# 2316-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.1 ////// 799/878 completed  //////  0 min 0.92 sec
# 2317-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 800/878 completed  //////  0 min 0.92 sec
# 2318-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.3 ////// 801/878 completed  //////  0 min 0.92 sec
# 2319-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.4 ////// 802/878 completed  //////  0 min 0.84 sec
# 2320-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.5 ////// 803/878 completed  //////  0 min 0.84 sec
# 2321-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.1 ////// 804/878 completed  //////  0 min 0.89 sec
# 2322-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 805/878 completed  //////  0 min 0.91 sec
# 2323-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 806/878 completed  //////  0 min 0.98 sec
# 2324-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.4 ////// 807/878 completed  //////  0 min 1.20 sec
# 2325-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.1 ////// 808/878 completed  //////  0 min 0.94 sec
# 2326-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.2 ////// 809/878 completed  //////  0 min 1.00 sec
# 2327-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.3 ////// 810/878 completed  //////  0 min 0.92 sec
# 2328-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.4 ////// 811/878 completed  //////  0 min 0.94 sec
# 2329-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.5 ////// 812/878 completed  //////  0 min 0.90 sec
# 2330-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.6 ////// 813/878 completed  //////  0 min 0.85 sec
# 2331-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.7 ////// 814/878 completed  //////  0 min 0.96 sec
# 2332-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.8 ////// 815/878 completed  //////  0 min 1.00 sec
# 2333-699-4-4-Crossmodal-PER-deep-(-4.92 mm)-TT16.1 ////// 816/878 completed  //////  0 min 0.92 sec
# 2334-699-4-4-Crossmodal-PER-deep-(-4.92 mm)-TT16.2 ////// 817/878 completed  //////  0 min 0.82 sec
# 2335-699-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT17.1 ////// 818/878 completed  //////  0 min 0.86 sec
# 2336-699-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT17.2 ////// 819/878 completed  //////  0 min 0.83 sec
# 2338-699-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT17.4 ////// 820/878 completed  //////  0 min 0.85 sec
# 2339-699-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT17.5 ////// 821/878 completed  //////  0 min 0.78 sec
# 2342-699-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT17.8 ////// 822/878 completed  //////  0 min 0.95 sec
# 2343-699-4-4-Crossmodal-PER-deep-(-5.64 mm)-TT18.1 ////// 823/878 completed  //////  0 min 0.96 sec
# 2344-699-4-4-Crossmodal-Visual-deep-(-6.48 mm)-TT24.1 ////// 824/878 completed  //////  0 min 0.90 sec
# 2345-699-4-4-Crossmodal-Visual-deep-(-6.48 mm)-TT24.2 ////// 825/878 completed  //////  0 min 1.03 sec
# 2346-699-4-4-Crossmodal-Visual-deep-(-6.48 mm)-TT24.3 ////// 826/878 completed  //////  0 min 1.05 sec
# 2347-699-4-4-Crossmodal-Visual-deep-(-6.48 mm)-TT24.4 ////// 827/878 completed  //////  0 min 0.92 sec
# 2348-699-5-5-Crossmodal-Visual-deep-(-6.72 mm)-TT2.1 ////// 828/878 completed  //////  0 min 0.84 sec
# 2349-699-5-5-Crossmodal-PER-deep-(-5.52 mm)-TT8.1 ////// 829/878 completed  //////  0 min 0.89 sec
# 2350-699-5-5-Crossmodal-PER-deep-(-5.2 mm)-TT9.1 ////// 830/878 completed  //////  0 min 0.86 sec
# 2351-699-5-5-Crossmodal-PER-deep-(-5.2 mm)-TT9.2 ////// 831/878 completed  //////  0 min 0.88 sec
# 2352-699-5-5-Crossmodal-PER-deep-(-5.2 mm)-TT9.3 ////// 832/878 completed  //////  0 min 0.81 sec
# 2354-699-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 834/878 completed  //////  0 min 0.91 sec
# 2356-699-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT10.4 ////// 835/878 completed  //////  0 min 0.89 sec
# 2357-699-5-5-Crossmodal-PER-superficial-(-4.68 mm)-TT11.1 ////// 836/878 completed  //////  0 min 0.84 sec
# 2361-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 839/878 completed  //////  0 min 0.81 sec
# 2362-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.3 ////// 840/878 completed  //////  0 min 0.91 sec
# 2363-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.4 ////// 841/878 completed  //////  0 min 0.97 sec
# 2364-699-5-5-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.1 ////// 842/878 completed  //////  0 min 0.82 sec
# 2365-699-5-5-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 843/878 completed  //////  0 min 0.88 sec
# 2366-699-5-5-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 844/878 completed  //////  0 min 0.93 sec
# 2367-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.1 ////// 845/878 completed  //////  0 min 1.14 sec
# 2368-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.2 ////// 846/878 completed  //////  0 min 1.23 sec
# 2369-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.3 ////// 847/878 completed  //////  0 min 0.97 sec
# 2370-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.4 ////// 848/878 completed  //////  0 min 1.27 sec
# 2371-699-5-5-Crossmodal-PER-deep-(-4.92 mm)-TT16.1 ////// 849/878 completed  //////  0 min 0.85 sec
# 2372-699-5-5-Crossmodal-PER-deep-(-4.92 mm)-TT16.2 ////// 850/878 completed  //////  0 min 0.80 sec
# 2373-699-5-5-Crossmodal-PER-deep-(-4.92 mm)-TT16.3 ////// 851/878 completed  //////  0 min 0.93 sec
# 2374-699-5-5-Crossmodal-PER-deep-(-5.28 mm)-TT17.1 ////// 852/878 completed  //////  0 min 0.88 sec
# 2375-699-5-5-Crossmodal-PER-deep-(-5.28 mm)-TT17.2 ////// 853/878 completed  //////  0 min 0.86 sec
# 2376-699-5-5-Crossmodal-PER-deep-(-5.28 mm)-TT17.3 ////// 854/878 completed  //////  0 min 0.81 sec
# 2380-699-5-5-Crossmodal-PER-deep-(-5.28 mm)-TT17.7 ////// 855/878 completed  //////  0 min 0.86 sec
# 2381-699-5-5-Crossmodal-PER-superficial-(-5.64 mm)-TT18.1 ////// 856/878 completed  //////  0 min 0.88 sec
# 2382-699-5-5-Crossmodal-PER-superficial-(-6.24 mm)-TT22.1 ////// 857/878 completed  //////  0 min 1.14 sec
# 2383-699-5-5-Crossmodal-Visual-superficial-(-6.36 mm)-TT23.1 ////// 858/878 completed  //////  0 min 1.10 sec
# 2385-699-6-6-Crossmodal-PER-superficial-(-5.52 mm)-TT7.1 ////// 859/878 completed  //////  0 min 0.88 sec
# 2386-699-6-6-Crossmodal-PER-superficial-(-5.52 mm)-TT7.2 ////// 860/878 completed  //////  0 min 0.79 sec
# 2387-699-6-6-Crossmodal-PER-superficial-(-4.68 mm)-TT11.1 ////// 861/878 completed  //////  0 min 0.93 sec
# 2388-699-6-6-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.1 ////// 862/878 completed  //////  0 min 1.08 sec
# 2389-699-6-6-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.2 ////// 863/878 completed  //////  0 min 1.07 sec
# 2391-699-6-6-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.1 ////// 864/878 completed  //////  0 min 0.99 sec
# 2392-699-6-6-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 865/878 completed  //////  0 min 0.81 sec
# 2393-699-6-6-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.3 ////// 866/878 completed  //////  0 min 0.88 sec
# 2394-699-6-6-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.4 ////// 867/878 completed  //////  0 min 0.85 sec
# 2396-699-6-6-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.1 ////// 869/878 completed  //////  0 min 0.88 sec
# 2397-699-6-6-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 870/878 completed  //////  0 min 0.81 sec
# 2398-699-6-6-Crossmodal-PER-deep-(-5.28 mm)-TT17.1 ////// 871/878 completed  //////  0 min 0.80 sec
# 2402-699-6-6-Crossmodal-PER-deep-(-5.28 mm)-TT17.5 ////// 872/878 completed  //////  0 min 0.92 sec
# 2403-699-6-6-Crossmodal-PER-deep-(-5.28 mm)-TT17.6 ////// 873/878 completed  //////  0 min 0.85 sec
# 2404-699-6-6-Crossmodal-PER-deep-(-5.28 mm)-TT17.7 ////// 874/878 completed  //////  0 min 0.85 sec
# 2409-699-6-6-Crossmodal-Visual-superficial-(-6.36 mm)-TT23.1 ////// 878/878 completed  //////  0 min 1.05 sec
# CPU times: total: 9min 45s
# Wall time: 11min 35s

# %%
f.close()
s.close()
print('END')
# Out:
# END
