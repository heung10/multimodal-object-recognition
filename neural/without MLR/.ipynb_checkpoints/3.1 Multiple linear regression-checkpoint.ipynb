# %% [markdown]
# ## Multiple linear regression
# This code runs multiple linear regression within object-selective epoch defined based on ANOVA result.
#
# Response-selective neurons were filtered out by nested regression.

# %%
import os
from pathlib import Path
import numpy as np
import pandas as pd

from scipy import stats
from scipy.stats.mstats import zscore

from scipy.ndimage import gaussian_filter
from statsmodels.regression.linear_model import OLS
from statsmodels.tools import add_constant

import matplotlib as mpl
import matplotlib.pyplot as plt  

from datetime import date
import time

import random

from joblib import Parallel, delayed

import h5py

# %%
# no top and right spines in all plots
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

# %%
mother_path = Path('D:/Multi-modal project/')

# %% [markdown]
# ### Parameter setting

# %%
num_iter = 1000

gauss_sigma = 2

# colors for multimodal, vis-only, aud-only conditions
color = ['mediumorchid','cornflowerblue','lightcoral','gray']
color2 = ['cyan','magenta','brown']
linestyle = ['-',':']

today = str(date.today())

# %% [markdown]
# ### Data preparation

# %%
save_path = mother_path /'analysis'/'result'/'3.1 Multiple linear regression'/today
cell_path = mother_path/'analysis'/'result'/'zFR export'/'13-Jun-2023'
data_path = mother_path /'analysis'/'result'/'3. ANOVA'

cell_list = os.listdir(cell_path)

# load hdf5 files containing ANOVA results
f = h5py.File(data_path/'2023-06-14'/'2023-06-14_ANOVA_result.hdf5','r')

# make hdf5 save file
os.makedirs(save_path,exist_ok=True)
s = h5py.File(save_path/f'{today}_multiple_regression_result.hdf5','w')

# %% [markdown]
# # Data analysis

# %%
def MLR(fr,x1,x2,shuffle):
    """
    This function performs multiple linear regression to estimate firing rates within
    object-selective epoch
    """
    # trial condition shuffling
    if shuffle:
        state = np.random.get_state()
        x1 = np.random.permutation(x1)
        np.random.set_state(state)
        x2 = np.random.permutation(x2)
    
    lr1 = OLS(zscore(fr),add_constant(zscore(x1))).fit()
    lr2 = OLS(zscore(fr),add_constant(zscore(x2))).fit()
    
    beta_coef, beta_coef_choice = lr1.params[1:], lr2.params[1:]

    AIC, AIC_choice = lr1.aic, lr2.aic
    BIC, BIC_choice = lr1.bic, lr2.bic
    
    if shuffle==0:
        pval, pval_choice = lr1.pvalues[1:], lr2.pvalues[1:]    
    else:
        pval, pval_choice = 0, 0
        
    return beta_coef, beta_coef_choice, pval, pval_choice, AIC, AIC_choice, BIC, BIC_choice

# %%
def plot_SDF_beta(df,linewidth,smooth,save,save_format):
    """
    This function plots mean firing rate patterns of each stimulus condition
    and beta coefficients for visual and auditory terms in multiple linear regression.
    """
    cond = [(df.Type=='Multimodal')&(df.RWD_Loc==boy_goal),
            (df.Type=='Multimodal')&(df.RWD_Loc==egg_goal),
            (df.Type=='Visual')&(df.RWD_Loc==boy_goal),
            (df.Type=='Visual')&(df.RWD_Loc==egg_goal),
            (df.Type=='Auditory')&(df.RWD_Loc==boy_goal),
            (df.Type=='Auditory')&(df.RWD_Loc==egg_goal),
            (df.Type=='Elemental')&(df.RWD_Loc==boy_goal),
            (df.Type=='Elemental')&(df.RWD_Loc==egg_goal)]
    
    cell_full_name = cell_name.strip('.csv')
    
    fr_mean = np.zeros((10,90))
    fr_sem = np.zeros((10,90))
    for i in range(8):
        fr_mean[i,:] = df[cond[i]].iloc[:,fr_id:fr_id+90].to_numpy().mean(axis=0)
        fr_sem[i,:] = stats.sem(df[cond[i]].iloc[:,fr_id:fr_id+90].to_numpy())
    
    fr_mean[8,:] = (fr_mean[0,:]+fr_mean[2,:]+fr_mean[4,:])/3    # mean firing rates for BOY
    fr_mean[9,:] = (fr_mean[1,:]+fr_mean[3,:]+fr_mean[5,:])/3    # mean firing rates for EGG
    
    fr_sem[8,:] = (fr_sem[0,:]+fr_sem[2,:]+fr_sem[4,:])/3    # SEM for BOY
    fr_sem[9,:] = (fr_sem[1,:]+fr_sem[3,:]+fr_sem[5,:])/3    # SEM for EGG
    
    if smooth:
        for i in range(10):
            fr_mean[i,:] = gaussian_filter(fr_mean[i,:],sigma=gauss_sigma)
            fr_sem[i,:] = gaussian_filter(fr_sem[i,:],sigma=gauss_sigma)
            
    y_max = np.ceil(np.max(fr_mean+fr_sem))
    y_min = 0
    
    fig,ax = plt.subplots(2,2,figsize=(7,5))
    plt.suptitle(cell_full_name,fontsize=15);
    x = np.arange(90)*10
    
    # Fring rates of each object
    object_max = np.ceil(np.max(fr_mean[8:9,:]+fr_sem[8:9,:]))
    object_min = 0
    ax[0,0].plot(x,fr_mean[8,:],color='black',linewidth=linewidth)
    ax[0,0].fill_between(x,fr_mean[8,:]-fr_sem[8,:],fr_mean[8,:]+fr_sem[8,:],color='black',alpha=0.2)
    ax[0,0].plot(x,fr_mean[9,:],color='black',linewidth=linewidth,linestyle=':')
    ax[0,0].fill_between(x,fr_mean[9,:]-fr_sem[9,:],fr_mean[9,:]+fr_sem[9,:],color='black',alpha=0.2)        
    if response_cell == 1:
        ax[0,0].plot(x,fr_mean[6,:],color='gray',linewidth=1.5)
        ax[0,0].plot(x,fr_mean[7,:],color='gray',linewidth=1.5,linestyle=':')    
    ax[0,0].scatter(object_bin*10,np.tile(object_max-0.1,(len(object_bin),1)),color='black',marker='*',s=7)
    ax[0,0].set_yticks([object_min, object_max])
    ax[0,0].set_ylim([object_min, object_max])
    ax[0,0].set_ylabel('z-scored FR',fontsize=13)
    ax[0,0].set_xlabel('Time (ms)',fontsize=13)  
    ax[0,0].set_xticks([0,400,900])
    ax[0,0].set_xlim([0,900])
    
    # Firing rates of each modality condition
    for i in range(6):
        if i%2==0:
            ls = linestyle[0]
        else:
            ls = linestyle[1]          
        ax[1,0].plot(x,fr_mean[i,:],color=color[divmod(i,2)[0]],linewidth=linewidth,linestyle=ls)
        ax[1,0].fill_between(x,fr_mean[i,:]-fr_sem[i,:],fr_mean[i,:]+fr_sem[i,:],color=color[divmod(i,2)[0]],alpha=0.2)
    ax[1,0].scatter(object_bin*10,np.tile(y_max-0.1,(len(object_bin),1)),color='black',marker='*',s=7)
    ax[1,0].set_yticks([y_min, y_max])
    ax[1,0].set_ylim([y_min, y_max])
    ax[1,0].set_ylabel('z-scored FR',fontsize=13)
    ax[1,0].set_xlabel('Time (ms)',fontsize=13)  
    ax[1,0].set_xticks([0,400,900])
    ax[1,0].set_xlim([0,900])
    
    # Mean firing rates within object-selective epoch
    x = ['Boy-M','Boy-V','Boy-A','Egg-M','Egg-V','Egg-A']
    ax[0,1].bar(x,cond_mFR,yerr=cond_sem,
                color=['purple','blue','red','purple','blue','red'])
    ax[0,1].set_ylabel('mean FR',fontsize=13)
    ax[0,1].tick_params(axis='x',labelrotation=45)
    ax[0,1].set_yticks(np.arange(y_min,y_max+0.1,1))
    ax[0,1].set_ylim([y_min,y_max])
    
    # Beta coefficient of multiple linear regression within object-selective epoch
    x = ['Boy-image','Boy-sound','Egg-image','Egg-sound']
    sig = pval<0.05
    ax[1,1].bar(x,beta_coef,
                    color=['tab:cyan','tab:pink','tab:cyan','tab:pink'])
    if len(np.where(sig)[0])!=0:
        ax[1,1].scatter(np.where(sig)[0],np.tile(0.1,(sum(sig),1)),marker='*',color='black');
    ax[1,1].set_yticks(np.arange(-1,1.1,0.5))
    ax[1,1].set_ylim([-1,1])
    ax[1,1].set_ylabel('beta coefficient',fontsize=13);
    ax[1,1].tick_params(axis='x',labelrotation=45);
    
    
    plt.tight_layout()
    
    if save:
        fig_path = save_path / region / ('response' if response_cell else '')
        os.makedirs(fig_path, exist_ok=True)

        if save_format == 'png':
            plt.savefig(fig_path / f'{cell_full_name}.png', dpi=100, facecolor='white')
        elif save_format == 'svg':
            plt.savefig(fig_path / f'{cell_full_name}.svg')
        plt.close()

# %%
def save_result(f):
    """
    This function saves regression results into HDF5 format.
    """
    cell_group = f.create_group(str(cell_id))
    basic_group = f.create_group(f'{cell_id}/basic')
    extended_group = f.create_group(f'{cell_id}/extended')
    basic_shuffle_group = f.create_group(f'{cell_id}/basic_shuffle')
    extended_shuffle_group = f.create_group(f'{cell_id}/extended_shuffle')
    
    basic_group.create_dataset('beta_coef',data=beta_coef)
    basic_group.create_dataset('pval',data=pval)
    basic_group.create_dataset('AIC',data=AIC)
    basic_group.create_dataset('BIC',data=BIC)

    extended_group.create_dataset('beta_coef',data=beta_coef_choice)
    extended_group.create_dataset('pval',data=pval_choice)    
    extended_group.create_dataset('AIC',data=AIC_choice)
    extended_group.create_dataset('BIC',data=BIC_choice)    
    
    basic_shuffle_group.create_dataset('beta_coef',data=beta_coef_shuffle)
    basic_shuffle_group.create_dataset('AIC',data=AIC_shuffle)
    basic_shuffle_group.create_dataset('BIC',data=BIC_shuffle)

    extended_shuffle_group.create_dataset('beta_coef',data=beta_coef_choice_shuffle)
    extended_shuffle_group.create_dataset('AIC',data=AIC_choice_shuffle)
    extended_shuffle_group.create_dataset('BIC',data=BIC_choice_shuffle)           
    
    cell_group.attrs['Rat'] = rat_id
    cell_group.attrs['Region'] = region
    cell_group.attrs['Session'] = session_id
    cell_group.attrs['Response cell'] = response_cell

# %%
# %%time
for cell_run,cell_name in enumerate(cell_list):
    loop_start = time.time()
    # get information about the cell
    cell_info = cell_name.split('-')
    cell_id, rat_id, session_id, region = int(cell_info[0]), cell_info[1], cell_info[2], cell_info[5]
        
    # skip non object-selective cells
    if f[str(cell_id)].attrs['Object cell'] == 0:
        continue
        
    # load cell data
    df = pd.read_csv(cell_path/cell_name)
    df.drop(df[df.Correctness==0].index,inplace=True)
    df.reset_index(inplace=True,drop=True)
    df[['Visual','Auditory']] = df[['Visual','Auditory']].fillna('no')
    
    boy_goal = df.loc[df['Visual']=='Boy','RWD_Loc'].values[0]
    boy_aud = df.loc[df['RWD_Loc']==boy_goal,'Auditory'].values[0]
    
    egg_goal = df.loc[df['Visual']=='Egg','RWD_Loc'].values[0]
    egg_aud = df.loc[df['RWD_Loc']==egg_goal,'Auditory'].values[0]  
    
    df['Boy-V'] = (df['Visual'] == 'Boy').astype(int)
    df['Boy-A'] = (df['Auditory'] == boy_aud).astype(int)
    df['Egg-V'] = (df['Visual'] == 'Egg').astype(int)
    df['Egg-A'] = (df['Auditory'] == egg_aud).astype(int)
    
    df['Boy-int'] = df['Boy-V']*df['Boy-A']
    df['Egg-int'] = df['Egg-V']*df['Egg-A']
    
    df['Choice'] = (df['RWD_Loc']==boy_goal).astype(int) 
    
    fr_id = df.columns.get_loc('Var10')  # get the index of the first firing rate column
    fr = df.iloc[:,fr_id:fr_id+90].to_numpy()    # get firing rate data into array
       
    # set independent variables for multiple linear regression
    #x1 = df[['Boy-V','Boy-A','Boy-int','Egg-V','Egg-A','Egg-int']].to_numpy()
    #x2 = df[['Boy-V','Boy-A','Boy-int','Egg-V','Egg-A','Egg-int','Choice']].to_numpy()
    
    x1 = df[['Boy-V','Boy-A','Egg-V','Egg-A']].to_numpy()
    x2 = df[['Boy-V','Boy-A','Egg-V','Egg-A','Choice']].to_numpy()
    
    # load object-selective epoch (time bins)
    object_bin = np.array(f[f'{cell_id}/object_bin'])

    # get mean firing rates of object-selective epoch in each trial
    df['Object_mFR'] = df.iloc[:,fr_id+min(object_bin):fr_id+max(object_bin)+1].mean(axis=1)
    fr_id = df.columns.get_loc('Var10')  # get the index of the first firing rate column    
    fr = df['Object_mFR'].to_numpy()

    cond_mFR = [df.groupby(['Type','RWD_Loc']).mean()['Object_mFR']['Multimodal',boy_goal],
                df.groupby(['Type','RWD_Loc']).mean()['Object_mFR']['Visual',boy_goal],
                df.groupby(['Type','RWD_Loc']).mean()['Object_mFR']['Auditory',boy_goal],
                df.groupby(['Type','RWD_Loc']).mean()['Object_mFR']['Multimodal',egg_goal],
                df.groupby(['Type','RWD_Loc']).mean()['Object_mFR']['Visual',egg_goal],
                df.groupby(['Type','RWD_Loc']).mean()['Object_mFR']['Auditory',egg_goal]]  

    cond_sem = [df.groupby(['Type','RWD_Loc']).sem()['Object_mFR']['Multimodal',boy_goal],
                df.groupby(['Type','RWD_Loc']).sem()['Object_mFR']['Visual',boy_goal],
                df.groupby(['Type','RWD_Loc']).sem()['Object_mFR']['Auditory',boy_goal],
                df.groupby(['Type','RWD_Loc']).sem()['Object_mFR']['Multimodal',egg_goal],
                df.groupby(['Type','RWD_Loc']).sem()['Object_mFR']['Visual',egg_goal],
                df.groupby(['Type','RWD_Loc']).sem()['Object_mFR']['Auditory',egg_goal]]                        
    
    # multiple linear regression
    result = MLR(fr,x1,x2,0)

    beta_coef, beta_coef_choice = result[0], result[1]
    pval, pval_choice = result[2], result[3]
    AIC, AIC_choice = result[4], result[5]
    BIC, BIC_choice = result[6], result[7]
    
    # multiple linear regression (shuffling)
    shuffle_result = Parallel(n_jobs=-1)(delayed(MLR)(fr,x1,x2,1) for i in range(1000))   
    
    beta_coef_shuffle = np.array([r[0] for r in shuffle_result])
    beta_coef_choice_shuffle = np.array([r[1] for r in shuffle_result])    
    AIC_shuffle = np.array([r[4] for r in shuffle_result])
    AIC_choice_shuffle = np.array([r[5] for r in shuffle_result])      
    BIC_shuffle = np.array([r[6] for r in shuffle_result])
    BIC_choice_shuffle = np.array([r[7] for r in shuffle_result])

    # define response-selective neurons by model improvement after adding response term
    model_improv = AIC-AIC_choice
    if model_improv > np.percentile(AIC_shuffle-AIC_choice_shuffle,99):
        response_cell = 1
    else:
        response_cell = 0    
        
    plot_SDF_beta(df,2,1,1,'png')
    
    # save results into HDF5 format
    save_result(s)
            
    loop_end = time.time()
    loop_time = divmod(loop_end-loop_start,60)
    print(cell_name.strip('.csv'), f'////// {cell_run+1}/{len(cell_list)} completed  //////  {int(loop_time[0])} min {loop_time[1]:.2f} sec')
# Out:
# 0004-600-1-1-Crossmodal-TeV-deep-(-7.32 mm)-TT4.2 ////// 2/888 completed  //////  0 min 7.75 sec
# 0006-600-1-1-Crossmodal-PER-superficial-(-7.2 mm)-TT5.1 ////// 4/888 completed  //////  0 min 1.08 sec
# 0008-600-1-1-Crossmodal-PER-superficial-(-7.2 mm)-TT5.3 ////// 6/888 completed  //////  0 min 1.17 sec
# 0013-600-1-1-Crossmodal-PER-deep-(-6.48 mm)-TT8.2 ////// 9/888 completed  //////  0 min 1.05 sec
# 0015-600-1-1-Crossmodal-TeV-deep-(-6.36 mm)-TT9.1 ////// 11/888 completed  //////  0 min 1.08 sec
# 0016-600-1-1-Crossmodal-PER-deep-(-6.24 mm)-TT10.1 ////// 12/888 completed  //////  0 min 1.12 sec
# 0017-600-1-1-Crossmodal-PER-deep-(-6.24 mm)-TT10.2 ////// 13/888 completed  //////  0 min 1.02 sec
# 0018-600-1-1-Crossmodal-PER-superficial-(-6.24 mm)-TT13.1 ////// 14/888 completed  //////  0 min 1.05 sec
# 0021-600-1-1-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.1 ////// 15/888 completed  //////  0 min 1.22 sec
# 0024-600-1-1-Crossmodal-POR-deep-(-7.56 mm)-TT24.2 ////// 18/888 completed  //////  0 min 1.24 sec
# 0027-600-2-2-Crossmodal-PER-superficial-(-7.2 mm)-TT5.1 ////// 21/888 completed  //////  0 min 1.19 sec
# 0028-600-2-2-Crossmodal-PER-superficial-(-7.2 mm)-TT5.2 ////// 22/888 completed  //////  0 min 1.19 sec
# 0030-600-2-2-Crossmodal-PER-superficial-(-7.2 mm)-TT5.4 ////// 24/888 completed  //////  0 min 1.03 sec
# 0031-600-2-2-Crossmodal-TeV-deep-(-6.96 mm)-TT6.1 ////// 25/888 completed  //////  0 min 1.11 sec
# 0032-600-2-2-Crossmodal-TeV-deep-(-6.96 mm)-TT6.2 ////// 26/888 completed  //////  0 min 1.07 sec
# 0033-600-2-2-Crossmodal-PER-superficial-(-6.48 mm)-TT7.1 ////// 27/888 completed  //////  0 min 1.06 sec
# 0035-600-2-2-Crossmodal-PER-superficial-(-6.48 mm)-TT7.3 ////// 28/888 completed  //////  0 min 0.99 sec
# 0036-600-2-2-Crossmodal-PER-superficial-(-6.48 mm)-TT7.4 ////// 29/888 completed  //////  0 min 1.01 sec
# 0040-600-2-2-Crossmodal-PER-superficial-(-7.24 mm)-TT13.1 ////// 33/888 completed  //////  0 min 1.12 sec
# 0043-600-2-2-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.2 ////// 36/888 completed  //////  0 min 1.13 sec
# 0044-600-2-2-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.3 ////// 37/888 completed  //////  0 min 1.20 sec
# 0045-600-2-2-Crossmodal-TeV-deep-(-6.96 mm)-TT19.1 ////// 38/888 completed  //////  0 min 1.02 sec
# 0046-600-2-2-Crossmodal-POR-deep-(-7.56 mm)-TT24.1 ////// 39/888 completed  //////  0 min 1.10 sec
# 0048-600-2-2-Crossmodal-POR-deep-(-7.56 mm)-TT24.3 ////// 41/888 completed  //////  0 min 1.21 sec
# 0049-600-3-3-Crossmodal-PER-superficial-(-7.2 mm)-TT5.1 ////// 42/888 completed  //////  0 min 1.17 sec
# 0050-600-3-3-Crossmodal-PER-superficial-(-7.2 mm)-TT5.2 ////// 43/888 completed  //////  0 min 1.33 sec
# 0052-600-3-3-Crossmodal-PER-superficial-(-6.48 mm)-TT7.1 ////// 45/888 completed  //////  0 min 0.99 sec
# 0053-600-3-3-Crossmodal-PER-superficial-(-6.48 mm)-TT7.2 ////// 46/888 completed  //////  0 min 1.02 sec
# 0059-600-3-3-Crossmodal-POR-deep-(-7.56 mm)-TT24.1 ////// 50/888 completed  //////  0 min 1.04 sec
# 0062-600-4-4-Crossmodal-PER-superficial-(-7.2 mm)-TT5.2 ////// 53/888 completed  //////  0 min 1.20 sec
# 0063-600-4-4-Crossmodal-PER-deep-(-6.96 mm)-TT6.1 ////// 54/888 completed  //////  0 min 0.99 sec
# 0066-600-4-4-Crossmodal-PER-superficial-(-6.48 mm)-TT7.2 ////// 56/888 completed  //////  0 min 1.06 sec
# 0070-600-4-4-Crossmodal-PER-deep-(-6.24 mm)-TT10.1 ////// 60/888 completed  //////  0 min 0.96 sec
# 0073-600-4-4-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.1 ////// 63/888 completed  //////  0 min 1.17 sec
# 0076-600-4-4-Crossmodal-POR-deep-(-7.56 mm)-TT24.2 ////// 66/888 completed  //////  0 min 1.10 sec
# 0079-600-4-4-Crossmodal-POR-deep-(-7.56 mm)-TT24.5 ////// 69/888 completed  //////  0 min 1.19 sec
# 0082-600-5-5-Crossmodal-PER-superficial-(-7.2 mm)-TT5.3 ////// 71/888 completed  //////  0 min 0.97 sec
# 0084-600-5-5-Crossmodal-PER-superficial-(-6.48 mm)-TT7.1 ////// 73/888 completed  //////  0 min 1.29 sec
# 0085-600-5-5-Crossmodal-PER-deep-(-6.36 mm)-TT9.1 ////// 74/888 completed  //////  0 min 1.14 sec
# 0086-600-5-5-Crossmodal-PER-deep-(-6.24 mm)-TT10.1 ////// 75/888 completed  //////  0 min 1.28 sec
# 0087-600-5-5-Crossmodal-PER-deep-(-6.24 mm)-TT10.2 ////// 76/888 completed  //////  0 min 1.43 sec
# 0088-600-5-5-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.1 ////// 77/888 completed  //////  0 min 0.95 sec
# 0089-600-5-5-Crossmodal-TeV-superficial-(-6.96 mm)-TT17.2 ////// 78/888 completed  //////  0 min 1.24 sec
# 0091-600-5-5-Crossmodal-TeV-deep-(-7.44 mm)-TT21.1 ////// 80/888 completed  //////  0 min 1.04 sec
# 0096-600-5-5-Crossmodal-POR-deep-(-7.56 mm)-TT24.5 ////// 85/888 completed  //////  0 min 1.04 sec
# 0175-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.10 ////// 87/888 completed  //////  0 min 1.03 sec
# 0183-602-1-1-Crossmodal-PER-deep-(-5.28 mm)-TT6.8 ////// 94/888 completed  //////  0 min 1.53 sec
# 0185-602-1-1-Crossmodal-PER-deep-(-4.8 mm)-TT7.1 ////// 96/888 completed  //////  0 min 1.21 sec
# 0190-602-1-1-Crossmodal-TeV-deep-(-4.44 mm)-TT9.4 ////// 98/888 completed  //////  0 min 1.56 sec
# 0193-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.1 ////// 101/888 completed  //////  0 min 1.31 sec
# 0194-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.2 ////// 102/888 completed  //////  0 min 1.79 sec
# 0195-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.3 ////// 103/888 completed  //////  0 min 2.19 sec
# 0197-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.5 ////// 105/888 completed  //////  0 min 1.80 sec
# 0198-602-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT10.6 ////// 106/888 completed  //////  0 min 1.66 sec
# 0200-602-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 107/888 completed  //////  0 min 2.17 sec
# 0201-602-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 108/888 completed  //////  0 min 1.52 sec
# 0202-602-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.4 ////// 109/888 completed  //////  0 min 1.60 sec
# 0203-602-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.5 ////// 110/888 completed  //////  0 min 1.10 sec
# 0204-602-1-1-Crossmodal-PER-superficial-(-4.2 mm)-TT12.1 ////// 111/888 completed  //////  0 min 1.50 sec
# 0205-602-1-1-Crossmodal-PER-superficial-(-4.2 mm)-TT12.2 ////// 112/888 completed  //////  0 min 1.68 sec
# 0208-602-1-1-Crossmodal-Auditory-superficial-(-5.52 mm)-TT19.3 ////// 114/888 completed  //////  0 min 1.81 sec
# 0209-602-1-1-Crossmodal-TeV-superficial-(-5.52 mm)-TT20.1 ////// 115/888 completed  //////  0 min 1.40 sec
# 0210-602-1-1-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.1 ////// 116/888 completed  //////  0 min 1.51 sec
# 0211-602-1-1-Crossmodal-PER-superficial-(-5.4 mm)-TT22.1 ////// 117/888 completed  //////  0 min 1.00 sec
# 0216-602-1-1-Crossmodal-TeV-superficial-(-5.52 mm)-TT24.2 ////// 121/888 completed  //////  0 min 1.31 sec
# 0217-602-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT4.1 ////// 122/888 completed  //////  0 min 1.23 sec
# 0228-602-2-2-Crossmodal-TeV-deep-(-4.44 mm)-TT9.1 ////// 129/888 completed  //////  0 min 1.28 sec
# 0231-602-2-2-Crossmodal-TeV-deep-(-4.44 mm)-TT9.4 ////// 131/888 completed  //////  0 min 1.39 sec
# 0237-602-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT10.3 ////// 136/888 completed  //////  0 min 1.10 sec
# 0238-602-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT10.4 ////// 137/888 completed  //////  0 min 1.78 sec
# 0242-602-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.4 ////// 141/888 completed  //////  0 min 2.66 sec
# 0247-602-2-2-Crossmodal-PER-superficial-(-4.2 mm)-TT12.5 ////// 143/888 completed  //////  0 min 1.60 sec
# 0254-602-2-2-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.3 ////// 145/888 completed  //////  0 min 2.01 sec
# 0255-602-2-2-Crossmodal-PER-superficial-(-5.4 mm)-TT22.1 ////// 146/888 completed  //////  0 min 1.32 sec
# 0258-602-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT4.2 ////// 148/888 completed  //////  0 min 1.21 sec
# 0263-602-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT7.1 ////// 153/888 completed  //////  0 min 1.24 sec
# 0268-602-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT7.6 ////// 156/888 completed  //////  0 min 1.16 sec
# 0271-602-3-3-Crossmodal-PER-superficial-(-4.8 mm)-TT8.3 ////// 157/888 completed  //////  0 min 1.36 sec
# 0273-602-3-3-Crossmodal-PER-deep-(-4.44 mm)-TT9.1 ////// 158/888 completed  //////  0 min 1.53 sec
# 0274-602-3-3-Crossmodal-PER-deep-(-4.44 mm)-TT9.2 ////// 159/888 completed  //////  0 min 1.37 sec
# 0276-602-3-3-Crossmodal-PER-deep-(-4.44 mm)-TT9.4 ////// 160/888 completed  //////  0 min 1.45 sec
# 0286-602-3-3-Crossmodal-PER-superficial-(-4.2 mm)-TT12.1 ////// 168/888 completed  //////  0 min 1.68 sec
# 0287-602-3-3-Crossmodal-PER-superficial-(-4.2 mm)-TT12.2 ////// 169/888 completed  //////  0 min 1.46 sec
# 0292-602-3-3-Crossmodal-PER-superficial-(-4.2 mm)-TT12.7 ////// 171/888 completed  //////  0 min 1.49 sec
# 0313-602-4-4-Crossmodal-PER-superficial-(-5.28 mm)-TT6.3 ////// 180/888 completed  //////  0 min 1.53 sec
# 0314-602-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT7.1 ////// 181/888 completed  //////  0 min 1.24 sec
# 0322-602-4-4-Crossmodal-PER-deep-(-4.44 mm)-TT9.3 ////// 188/888 completed  //////  0 min 1.79 sec
# 0325-602-4-4-Crossmodal-PER-superficial-(-4.68 mm)-TT10.2 ////// 191/888 completed  //////  0 min 1.48 sec
# 0333-602-4-4-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.3 ////// 193/888 completed  //////  0 min 1.22 sec
# 0334-602-4-4-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.4 ////// 194/888 completed  //////  0 min 1.16 sec
# 0336-602-4-4-Crossmodal-PER-superficial-(-5.4 mm)-TT22.2 ////// 195/888 completed  //////  0 min 1.21 sec
# 0343-602-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT7.2 ////// 200/888 completed  //////  0 min 2.64 sec
# 0344-602-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT7.3 ////// 201/888 completed  //////  0 min 1.43 sec
# 0349-602-5-5-Crossmodal-PER-deep-(-4.44 mm)-TT9.1 ////// 203/888 completed  //////  0 min 1.39 sec
# 0350-602-5-5-Crossmodal-PER-deep-(-4.44 mm)-TT9.2 ////// 204/888 completed  //////  0 min 1.62 sec
# 0351-602-5-5-Crossmodal-PER-deep-(-4.44 mm)-TT9.3 ////// 205/888 completed  //////  0 min 1.71 sec
# 0356-602-5-5-Crossmodal-PER-superficial-(-4.68 mm)-TT10.3 ////// 208/888 completed  //////  0 min 1.75 sec
# 0357-602-5-5-Crossmodal-PER-superficial-(-4.68 mm)-TT10.4 ////// 209/888 completed  //////  0 min 1.46 sec
# 0359-602-5-5-Crossmodal-PER-superficial-(-4.2 mm)-TT12.1 ////// 210/888 completed  //////  0 min 1.58 sec
# 0366-602-5-5-Crossmodal-Auditory-superficial-(-5.52 mm)-TT19.2 ////// 212/888 completed  //////  0 min 1.65 sec
# 0371-602-5-5-Crossmodal-TeV-superficial-(-5.52 mm)-TT20.4 ////// 214/888 completed  //////  0 min 1.46 sec
# 0376-602-5-5-Crossmodal-TeV-superficial-(-5.64 mm)-TT21.3 ////// 216/888 completed  //////  0 min 1.20 sec
# 0987-640-1-1-Crossmodal-PER-deep-(-6.12 mm)-TT1.1 ////// 217/888 completed  //////  0 min 1.33 sec
# 0989-640-1-1-Crossmodal-fiber-na-(-6.12 mm)-TT3.1 ////// 218/888 completed  //////  0 min 1.84 sec
# 0990-640-1-1-Crossmodal-PER-deep-(-5.52 mm)-TT5.1 ////// 219/888 completed  //////  0 min 1.43 sec
# 0991-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.1 ////// 220/888 completed  //////  0 min 1.45 sec
# 0992-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 221/888 completed  //////  0 min 1.36 sec
# 0993-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 222/888 completed  //////  0 min 1.16 sec
# 0995-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.2 ////// 224/888 completed  //////  0 min 1.16 sec
# 0996-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.3 ////// 225/888 completed  //////  0 min 1.52 sec
# 0998-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.5 ////// 226/888 completed  //////  0 min 1.37 sec
# 0999-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.6 ////// 227/888 completed  //////  0 min 1.35 sec
# 1001-640-1-1-Crossmodal-PER-deep-(-4.56 mm)-TT13.8 ////// 228/888 completed  //////  0 min 1.27 sec
# 1009-640-1-1-Crossmodal-TeV-superficial-(-5.88 mm)-TT20.2 ////// 229/888 completed  //////  0 min 1.58 sec
# 1013-640-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT5.1 ////// 233/888 completed  //////  0 min 1.47 sec
# 1015-640-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT5.3 ////// 235/888 completed  //////  0 min 1.36 sec
# 1016-640-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT10.1 ////// 236/888 completed  //////  0 min 1.50 sec
# 1017-640-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 237/888 completed  //////  0 min 2.29 sec
# 1018-640-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT10.3 ////// 238/888 completed  //////  0 min 1.49 sec
# 1019-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.1 ////// 239/888 completed  //////  0 min 1.36 sec
# 1020-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 240/888 completed  //////  0 min 1.32 sec
# 1021-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 241/888 completed  //////  0 min 1.34 sec
# 1022-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.4 ////// 242/888 completed  //////  0 min 1.65 sec
# 1023-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.5 ////// 243/888 completed  //////  0 min 1.51 sec
# 1024-640-2-2-Crossmodal-PER-deep-(-4.56 mm)-TT11.6 ////// 244/888 completed  //////  0 min 1.66 sec
# 1025-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.1 ////// 245/888 completed  //////  0 min 1.50 sec
# 1026-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.2 ////// 246/888 completed  //////  0 min 1.44 sec
# 1027-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.3 ////// 247/888 completed  //////  0 min 1.69 sec
# 1028-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.4 ////// 248/888 completed  //////  0 min 1.35 sec
# 1029-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.5 ////// 249/888 completed  //////  0 min 1.44 sec
# 1030-640-2-2-Crossmodal-PER-superficial-(-4.56 mm)-TT13.6 ////// 250/888 completed  //////  0 min 1.61 sec
# 1033-640-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT16.1 ////// 251/888 completed  //////  0 min 1.37 sec
# 1034-640-2-2-Crossmodal-TeV-superficial-(-5.64 mm)-TT19.1 ////// 252/888 completed  //////  0 min 1.28 sec
# 1037-640-2-2-Crossmodal-TeV-deep-(-5.88 mm)-TT22.2 ////// 254/888 completed  //////  0 min 1.18 sec
# 1039-640-2-2-Crossmodal-TeV-deep-(-5.88 mm)-TT22.4 ////// 256/888 completed  //////  0 min 1.21 sec
# 1047-640-3-3-Crossmodal-iHPC-na-(-5.64 mm)-TT4.1 ////// 262/888 completed  //////  0 min 1.39 sec
# 1048-640-3-3-Crossmodal-iHPC-na-(-5.64 mm)-TT4.2 ////// 263/888 completed  //////  0 min 1.15 sec
# 1050-640-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT5.1 ////// 264/888 completed  //////  0 min 1.09 sec
# 1051-640-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT10.1 ////// 265/888 completed  //////  0 min 1.17 sec
# 1052-640-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 266/888 completed  //////  0 min 1.44 sec
# 1053-640-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT10.3 ////// 267/888 completed  //////  0 min 1.38 sec
# 1054-640-3-3-Crossmodal-PER-deep-(-4.8 mm)-TT10.4 ////// 268/888 completed  //////  0 min 1.26 sec
# 1055-640-3-3-Crossmodal-PER-deep-(-4.56 mm)-TT11.1 ////// 269/888 completed  //////  0 min 1.10 sec
# 1056-640-3-3-Crossmodal-PER-deep-(-4.56 mm)-TT11.2 ////// 270/888 completed  //////  0 min 1.09 sec
# 1057-640-3-3-Crossmodal-PER-deep-(-4.56 mm)-TT11.3 ////// 271/888 completed  //////  0 min 1.10 sec
# 1059-640-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT13.2 ////// 273/888 completed  //////  0 min 1.11 sec
# 1060-640-3-3-Crossmodal-PER-superficial-(-4.56 mm)-TT13.3 ////// 274/888 completed  //////  0 min 1.37 sec
# 1069-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.3 ////// 279/888 completed  //////  0 min 1.12 sec
# 1070-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.4 ////// 280/888 completed  //////  0 min 2.22 sec
# 1071-640-3-3-Crossmodal-TeV-deep-(-5.88 mm)-TT22.5 ////// 281/888 completed  //////  0 min 1.12 sec
# 1075-640-4-4-Crossmodal-fiber-na-(-6.12 mm)-TT3.1 ////// 285/888 completed  //////  0 min 1.28 sec
# 1076-640-4-4-Crossmodal-fiber-na-(-6.12 mm)-TT3.2 ////// 286/888 completed  //////  0 min 1.04 sec
# 1077-640-4-4-Crossmodal-fiber-na-(-6.12 mm)-TT3.3 ////// 287/888 completed  //////  0 min 1.06 sec
# 1078-640-4-4-Crossmodal-iHPC-na-(-5.64 mm)-TT4.1 ////// 288/888 completed  //////  0 min 1.36 sec
# 1079-640-4-4-Crossmodal-PER-superficial-(-5.52 mm)-TT6.1 ////// 289/888 completed  //////  0 min 0.95 sec
# 1080-640-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT10.1 ////// 290/888 completed  //////  0 min 1.34 sec
# 1081-640-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 291/888 completed  //////  0 min 1.33 sec
# 1082-640-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT10.3 ////// 292/888 completed  //////  0 min 1.39 sec
# 1085-640-4-4-Crossmodal-PER-deep-(-4.56 mm)-TT11.1 ////// 294/888 completed  //////  0 min 1.17 sec
# 1089-640-4-4-Crossmodal-TeV-superficial-(-5.88 mm)-TT20.1 ////// 295/888 completed  //////  0 min 1.19 sec
# 1091-640-4-4-Crossmodal-TeV-deep-(-5.88 mm)-TT22.1 ////// 296/888 completed  //////  0 min 1.20 sec
# 1095-640-4-4-Crossmodal-TeV-deep-(-5.88 mm)-TT22.5 ////// 299/888 completed  //////  0 min 1.40 sec
# 1096-640-4-4-Crossmodal-TeV-deep-(-5.88 mm)-TT22.6 ////// 300/888 completed  //////  0 min 1.25 sec
# 1097-640-5-5-Crossmodal-fiber-na-(-6.12 mm)-TT3.1 ////// 301/888 completed  //////  0 min 1.25 sec
# 1103-640-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT10.2 ////// 302/888 completed  //////  0 min 1.19 sec
# 1105-640-5-5-Crossmodal-PER-superficial-(-4.56 mm)-TT13.2 ////// 303/888 completed  //////  0 min 1.04 sec
# 1106-640-5-5-Crossmodal-PER-superficial-(-4.56 mm)-TT15.1 ////// 304/888 completed  //////  0 min 1.42 sec
# 1115-640-5-5-Crossmodal-TeV-deep-(-5.88 mm)-TT22.2 ////// 306/888 completed  //////  0 min 1.31 sec
# 1117-640-5-5-Crossmodal-TeV-deep-(-5.88 mm)-TT22.4 ////// 308/888 completed  //////  0 min 1.10 sec
# 1118-640-5-5-Crossmodal-TeV-deep-(-5.88 mm)-TT22.5 ////// 309/888 completed  //////  0 min 1.11 sec
# 1325-647-4-4-Crossmodal-PER-deep-(-6 mm)-TT5.2 ////// 312/888 completed  //////  0 min 1.10 sec
# 1327-647-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT11.1 ////// 313/888 completed  //////  0 min 1.19 sec
# 1330-647-4-4-Crossmodal-PER-deep-(-5.2 mm)-TT15.1 ////// 316/888 completed  //////  0 min 1.46 sec
# 1334-647-4-4-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.2 ////// 318/888 completed  //////  0 min 1.22 sec
# 1335-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.1 ////// 319/888 completed  //////  0 min 1.32 sec
# 1336-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.2 ////// 320/888 completed  //////  0 min 1.32 sec
# 1339-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.5 ////// 323/888 completed  //////  0 min 1.45 sec
# 1340-647-4-4-Crossmodal-PER-superficial-(-5.64 mm)-TT17.6 ////// 324/888 completed  //////  0 min 1.44 sec
# 1341-647-4-4-Crossmodal-PER-superficial-(-5.88 mm)-TT19.1 ////// 325/888 completed  //////  0 min 1.18 sec
# 1343-647-4-4-Crossmodal-PER-superficial-(-5.88 mm)-TT19.3 ////// 326/888 completed  //////  0 min 1.14 sec
# 1345-647-4-4-Crossmodal-PER-superficial-(-5.88 mm)-TT19.5 ////// 327/888 completed  //////  0 min 1.38 sec
# 1347-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 329/888 completed  //////  0 min 1.31 sec
# 1350-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.5 ////// 332/888 completed  //////  0 min 1.20 sec
# 1352-647-4-4-Crossmodal-TeV-deep-(-6.12 mm)-TT21.7 ////// 334/888 completed  //////  0 min 1.06 sec
# 1353-647-5-5-Crossmodal-PER-deep-(-6 mm)-TT5.1 ////// 335/888 completed  //////  0 min 0.98 sec
# 1354-647-5-5-Crossmodal-PER-deep-(-6 mm)-TT5.2 ////// 336/888 completed  //////  0 min 1.12 sec
# 1358-647-5-5-Crossmodal-PER-deep-(-5.4 mm)-TT9.1 ////// 339/888 completed  //////  0 min 2.50 sec
# 1361-647-5-5-Crossmodal-PER-superficial-(-5.28 mm)-TT11.2 ////// 341/888 completed  //////  0 min 1.12 sec
# 1362-647-5-5-Crossmodal-PER-superficial-(-5.4 mm)-TT13.1 ////// 342/888 completed  //////  0 min 1.95 sec
# 1363-647-5-5-Crossmodal-PER-deep-(-5.2 mm)-TT15.1 ////// 343/888 completed  //////  0 min 1.33 sec
# 1366-647-5-5-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.1 ////// 344/888 completed  //////  0 min 1.21 sec
# 1367-647-5-5-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.2 ////// 345/888 completed  //////  0 min 1.09 sec
# 1374-647-5-5-Crossmodal-PER-superficial-(-5.88 mm)-TT19.3 ////// 349/888 completed  //////  0 min 1.01 sec
# 1377-647-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 350/888 completed  //////  0 min 1.02 sec
# 1378-647-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 351/888 completed  //////  0 min 1.15 sec
# 1380-647-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 353/888 completed  //////  0 min 1.00 sec
# 1383-647-6-6-Crossmodal-PER-deep-(-5.4 mm)-TT9.1 ////// 355/888 completed  //////  0 min 0.98 sec
# 1391-647-6-6-Crossmodal-PER-deep-(-5.2 mm)-TT15.4 ////// 357/888 completed  //////  0 min 1.02 sec
# 1392-647-6-6-Crossmodal-PER-deep-(-5.2 mm)-TT15.5 ////// 358/888 completed  //////  0 min 1.55 sec
# 1393-647-6-6-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.1 ////// 359/888 completed  //////  0 min 1.54 sec
# 1394-647-6-6-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.2 ////// 360/888 completed  //////  0 min 1.29 sec
# 1395-647-6-6-Crossmodal-TeV-superficial-(-5.52 mm)-TT16.3 ////// 361/888 completed  //////  0 min 1.29 sec
# 1401-647-6-6-Crossmodal-PER-superficial-(-5.88 mm)-TT19.3 ////// 364/888 completed  //////  0 min 1.15 sec
# 1406-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 366/888 completed  //////  0 min 1.30 sec
# 1407-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 367/888 completed  //////  0 min 1.13 sec
# 1408-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 368/888 completed  //////  0 min 1.02 sec
# 1409-647-6-6-Crossmodal-TeV-deep-(-6.12 mm)-TT21.5 ////// 369/888 completed  //////  0 min 1.17 sec
# 1411-647-7-7-Crossmodal-PER-superficial-(-5.28 mm)-TT11.1 ////// 371/888 completed  //////  0 min 1.19 sec
# 1413-647-7-7-Crossmodal-PER-deep-(-5.2 mm)-TT15.2 ////// 372/888 completed  //////  0 min 1.18 sec
# 1414-647-7-7-Crossmodal-PER-deep-(-5.2 mm)-TT15.3 ////// 373/888 completed  //////  0 min 1.69 sec
# 1421-647-7-7-Crossmodal-PER-superficial-(-5.88 mm)-TT19.2 ////// 375/888 completed  //////  0 min 1.14 sec
# 1423-647-7-7-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 376/888 completed  //////  0 min 1.40 sec
# 1425-647-7-7-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 377/888 completed  //////  0 min 1.45 sec
# 1526-654-1-1-Crossmodal-Visual-superficial-(-6.6 mm)-TT1.3 ////// 378/888 completed  //////  0 min 1.42 sec
# 1527-654-1-1-Crossmodal-Visual-superficial-(-6.6 mm)-TT1.4 ////// 379/888 completed  //////  0 min 1.11 sec
# 1529-654-1-1-Crossmodal-Visual-superficial-(-6.48 mm)-TT3.1 ////// 380/888 completed  //////  0 min 1.05 sec
# 1530-654-1-1-Crossmodal-Visual-deep-(-5.64 mm)-TT6.1 ////// 381/888 completed  //////  0 min 1.03 sec
# 1531-654-1-1-Crossmodal-Visual-deep-(-5.64 mm)-TT6.2 ////// 382/888 completed  //////  0 min 1.14 sec
# 1532-654-1-1-Crossmodal-Visual-superficial-(-5.28 mm)-TT8.1 ////// 383/888 completed  //////  0 min 1.35 sec
# 1533-654-1-1-Crossmodal-PER-deep-(-5.4 mm)-TT10.1 ////// 384/888 completed  //////  0 min 0.92 sec
# 1534-654-1-1-Crossmodal-PER-deep-(-5.4 mm)-TT10.2 ////// 385/888 completed  //////  0 min 1.02 sec
# 1536-654-1-1-Crossmodal-PER-deep-(-5.4 mm)-TT10.4 ////// 387/888 completed  //////  0 min 1.50 sec
# 1543-654-1-1-Crossmodal-Auditory-deep-(-4.8 mm)-TT12.1 ////// 391/888 completed  //////  0 min 1.34 sec
# 1548-654-1-1-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.1 ////// 393/888 completed  //////  0 min 1.29 sec
# 1549-654-1-1-Crossmodal-Auditory-deep-(-5.2 mm)-TT16.1 ////// 394/888 completed  //////  0 min 1.01 sec
# 1551-654-1-1-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.2 ////// 396/888 completed  //////  0 min 1.22 sec
# 1553-654-1-1-Crossmodal-Auditory-superficial-(-6.12 mm)-TT20.2 ////// 398/888 completed  //////  0 min 1.30 sec
# 1554-654-1-1-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 399/888 completed  //////  0 min 1.47 sec
# 1555-654-1-1-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 400/888 completed  //////  0 min 1.08 sec
# 1556-654-1-1-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 401/888 completed  //////  0 min 1.01 sec
# 1557-654-1-1-Crossmodal-Auditory-superficial-(-6.6 mm)-TT23.1 ////// 402/888 completed  //////  0 min 1.08 sec
# 1558-654-1-1-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 403/888 completed  //////  0 min 1.08 sec
# 1560-654-1-1-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.3 ////// 404/888 completed  //////  0 min 1.04 sec
# 1561-654-1-1-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.4 ////// 405/888 completed  //////  0 min 2.38 sec
# 1567-654-2-2-Crossmodal-Visual-superficial-(-6.48 mm)-TT3.1 ////// 406/888 completed  //////  0 min 1.04 sec
# 1568-654-2-2-Crossmodal-Visual-deep-(-6.24 mm)-TT4.1 ////// 407/888 completed  //////  0 min 1.03 sec
# 1569-654-2-2-Crossmodal-Visual-deep-(-6.24 mm)-TT4.2 ////// 408/888 completed  //////  0 min 1.14 sec
# 1570-654-2-2-Crossmodal-Visual-deep-(-5.64 mm)-TT6.1 ////// 409/888 completed  //////  0 min 1.03 sec
# 1571-654-2-2-Crossmodal-Visual-superficial-(-5.28 mm)-TT8.1 ////// 410/888 completed  //////  0 min 1.44 sec
# 1576-654-2-2-Crossmodal-PER-deep-(-5.4 mm)-TT10.5 ////// 413/888 completed  //////  0 min 1.25 sec
# 1579-654-2-2-Crossmodal-PER-superficial-(-4.68 mm)-TT13.2 ////// 414/888 completed  //////  0 min 1.56 sec
# 1582-654-2-2-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.1 ////// 415/888 completed  //////  0 min 1.39 sec
# 1583-654-2-2-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.2 ////// 416/888 completed  //////  0 min 1.22 sec
# 1584-654-2-2-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.3 ////// 417/888 completed  //////  0 min 1.26 sec
# 1585-654-2-2-Crossmodal-Auditory-deep-(-5.88 mm)-TT18.1 ////// 418/888 completed  //////  0 min 1.05 sec
# 1587-654-2-2-Crossmodal-Auditory-superficial-(-6.12 mm)-TT20.2 ////// 419/888 completed  //////  0 min 1.10 sec
# 1589-654-2-2-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 421/888 completed  //////  0 min 1.04 sec
# 1591-654-2-2-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 423/888 completed  //////  0 min 0.95 sec
# 1593-654-2-2-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 425/888 completed  //////  0 min 0.94 sec
# 1595-654-2-2-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.3 ////// 426/888 completed  //////  0 min 0.95 sec
# 1598-654-3-3-Crossmodal-Visual-superficial-(-6.6 mm)-TT1.3 ////// 428/888 completed  //////  0 min 1.07 sec
# 1599-654-3-3-Crossmodal-Visual-superficial-(-6.6 mm)-TT1.4 ////// 429/888 completed  //////  0 min 1.13 sec
# 1601-654-3-3-Crossmodal-Visual-deep-(-6.36 mm)-TT2.1 ////// 431/888 completed  //////  0 min 1.11 sec
# 1603-654-3-3-Crossmodal-Visual-deep-(-6.24 mm)-TT4.1 ////// 433/888 completed  //////  0 min 1.09 sec
# 1604-654-3-3-Crossmodal-Visual-deep-(-5.64 mm)-TT6.1 ////// 434/888 completed  //////  0 min 1.24 sec
# 1606-654-3-3-Crossmodal-Visual-deep-(-5.64 mm)-TT6.3 ////// 436/888 completed  //////  0 min 1.14 sec
# 1607-654-3-3-Crossmodal-Auditory-deep-(-4.8 mm)-TT12.1 ////// 437/888 completed  //////  0 min 1.20 sec
# 1609-654-3-3-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.1 ////// 438/888 completed  //////  0 min 1.10 sec
# 1610-654-3-3-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.2 ////// 439/888 completed  //////  0 min 1.44 sec
# 1611-654-3-3-Crossmodal-Tev-deep-(-5.88 mm)-TT18.1 ////// 440/888 completed  //////  0 min 1.12 sec
# 1612-654-3-3-Crossmodal-Tev-deep-(-5.88 mm)-TT18.2 ////// 441/888 completed  //////  0 min 1.58 sec
# 1614-654-3-3-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.2 ////// 443/888 completed  //////  0 min 1.03 sec
# 1615-654-3-3-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.3 ////// 444/888 completed  //////  0 min 1.20 sec
# 1617-654-3-3-Crossmodal-TeV-deep-(-6.12 mm)-TT21.2 ////// 446/888 completed  //////  0 min 0.97 sec
# 1622-654-3-3-Crossmodal-Tev-superficial-(-6.6 mm)-TT23.3 ////// 449/888 completed  //////  0 min 1.01 sec
# 1623-654-3-3-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 450/888 completed  //////  0 min 1.28 sec
# 1624-654-3-3-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.2 ////// 451/888 completed  //////  0 min 1.13 sec
# 1625-654-3-3-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.3 ////// 452/888 completed  //////  0 min 1.19 sec
# 1630-654-4-4-Crossmodal-Visual-superficial-(-6.6 mm)-TT1.4 ////// 454/888 completed  //////  0 min 1.17 sec
# 1632-654-4-4-Crossmodal-Auditory-deep-(-4.8 mm)-TT12.1 ////// 455/888 completed  //////  0 min 1.39 sec
# 1634-654-4-4-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.1 ////// 456/888 completed  //////  0 min 1.06 sec
# 1635-654-4-4-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.2 ////// 457/888 completed  //////  0 min 1.04 sec
# 1636-654-4-4-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.3 ////// 458/888 completed  //////  0 min 1.01 sec
# 1637-654-4-4-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.4 ////// 459/888 completed  //////  0 min 1.00 sec
# 1638-654-4-4-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.5 ////// 460/888 completed  //////  0 min 1.15 sec
# 1643-654-4-4-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 463/888 completed  //////  0 min 1.02 sec
# 1644-654-5-5-Crossmodal-Visual-superficial-(-5.28 mm)-TT8.1 ////// 464/888 completed  //////  0 min 1.50 sec
# 1645-654-5-5-Crossmodal-Visual-superficial-(-5.28 mm)-TT8.2 ////// 465/888 completed  //////  0 min 1.06 sec
# 1646-654-5-5-Crossmodal-PER-superficial-(-5.52 mm)-TT11.1 ////// 466/888 completed  //////  0 min 1.04 sec
# 1647-654-5-5-Crossmodal-Auditory-deep-(-4.8 mm)-TT12.1 ////// 467/888 completed  //////  0 min 1.72 sec
# 1651-654-5-5-Crossmodal-Auditory-deep-(-4.8 mm)-TT14.1 ////// 468/888 completed  //////  0 min 1.44 sec
# 1656-654-5-5-Crossmodal-Tev-deep-(-5.88 mm)-TT18.2 ////// 473/888 completed  //////  0 min 1.23 sec
# 1657-654-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.1 ////// 474/888 completed  //////  0 min 1.34 sec
# 1659-654-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.3 ////// 475/888 completed  //////  0 min 1.17 sec
# 1660-654-5-5-Crossmodal-TeV-deep-(-6.12 mm)-TT21.4 ////// 476/888 completed  //////  0 min 0.99 sec
# 1662-654-5-5-Crossmodal-Tev-superficial-(-6.6 mm)-TT23.1 ////// 478/888 completed  //////  0 min 1.03 sec
# 1667-654-5-5-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.5 ////// 481/888 completed  //////  0 min 1.04 sec
# 1668-654-5-5-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.6 ////// 482/888 completed  //////  0 min 1.12 sec
# 1670-654-6-6-Crossmodal-Auditory-deep-(-4.8 mm)-TT12.1 ////// 483/888 completed  //////  0 min 2.91 sec
# 1674-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.1 ////// 485/888 completed  //////  0 min 1.00 sec
# 1675-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.2 ////// 486/888 completed  //////  0 min 1.18 sec
# 1676-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT20.3 ////// 487/888 completed  //////  0 min 1.31 sec
# 1677-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT21.1 ////// 488/888 completed  //////  0 min 1.11 sec
# 1679-654-6-6-Crossmodal-TeV-superficial-(-6.12 mm)-TT21.3 ////// 489/888 completed  //////  0 min 1.12 sec
# 1684-654-6-6-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.1 ////// 491/888 completed  //////  0 min 1.22 sec
# 1685-654-6-6-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.2 ////// 492/888 completed  //////  0 min 1.07 sec
# 1686-654-6-6-Crossmodal-Auditory-deep-(-6.24 mm)-TT24.3 ////// 493/888 completed  //////  0 min 1.05 sec
# 1771-679-1-1-Crossmodal-Visual-deep-(-6.24 mm)-TT2.1 ////// 496/888 completed  //////  0 min 1.03 sec
# 1772-679-1-1-Crossmodal-Visual-deep-(-6.24 mm)-TT2.2 ////// 497/888 completed  //////  0 min 0.96 sec
# 1773-679-1-1-Crossmodal-Visual-deep-(-6.24 mm)-TT2.3 ////// 498/888 completed  //////  0 min 1.38 sec
# 1774-679-1-1-Crossmodal-Visual-deep-(-6.24 mm)-TT2.4 ////// 499/888 completed  //////  0 min 1.07 sec
# 1776-679-1-1-Crossmodal-Tev-deep-(-4.68 mm)-TT10.1 ////// 500/888 completed  //////  0 min 1.08 sec
# 1777-679-1-1-Crossmodal-Tev-deep-(-4.68 mm)-TT10.2 ////// 501/888 completed  //////  0 min 1.03 sec
# 1778-679-1-1-Crossmodal-Tev-deep-(-4.68 mm)-TT10.3 ////// 502/888 completed  //////  0 min 0.97 sec
# 1779-679-1-1-Crossmodal-Visual-deep-(-4.56 mm)-TT11.1 ////// 503/888 completed  //////  0 min 1.30 sec
# 1781-679-1-1-Crossmodal-Visual-deep-(-4.56 mm)-TT13.2 ////// 504/888 completed  //////  0 min 1.34 sec
# 1782-679-1-1-Crossmodal-Visual-deep-(-4.56 mm)-TT13.3 ////// 505/888 completed  //////  0 min 1.26 sec
# 1784-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.2 ////// 507/888 completed  //////  0 min 1.20 sec
# 1785-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.3 ////// 508/888 completed  //////  0 min 1.29 sec
# 1786-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.4 ////// 509/888 completed  //////  0 min 1.05 sec
# 1787-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.5 ////// 510/888 completed  //////  0 min 1.08 sec
# 1788-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.6 ////// 511/888 completed  //////  0 min 1.01 sec
# 1789-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.7 ////// 512/888 completed  //////  0 min 1.28 sec
# 1790-679-1-1-Crossmodal-Visual-deep-(-4.44 mm)-TT14.8 ////// 513/888 completed  //////  0 min 1.14 sec
# 1791-679-1-1-Crossmodal-Visual-deep-(-4.68 mm)-TT15.1 ////// 514/888 completed  //////  0 min 1.15 sec
# 1793-679-1-1-Crossmodal-Visual-deep-(-4.68 mm)-TT15.3 ////// 515/888 completed  //////  0 min 1.05 sec
# 1794-679-1-1-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.1 ////// 516/888 completed  //////  0 min 1.04 sec
# 1795-679-1-1-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.2 ////// 517/888 completed  //////  0 min 0.99 sec
# 1796-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.1 ////// 518/888 completed  //////  0 min 1.12 sec
# 1797-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.2 ////// 519/888 completed  //////  0 min 1.24 sec
# 1798-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.3 ////// 520/888 completed  //////  0 min 1.13 sec
# 1799-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.4 ////// 521/888 completed  //////  0 min 1.20 sec
# 1800-679-1-1-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.5 ////// 522/888 completed  //////  0 min 1.23 sec
# 1802-679-1-1-Crossmodal-Auditory-deep-(-5.52 mm)-TT20.1 ////// 523/888 completed  //////  0 min 1.30 sec
# 1805-679-1-1-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.1 ////// 525/888 completed  //////  0 min 1.17 sec
# 1806-679-1-1-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.2 ////// 526/888 completed  //////  0 min 1.06 sec
# 1807-679-1-1-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.3 ////// 527/888 completed  //////  0 min 0.98 sec
# 1808-679-1-1-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.4 ////// 528/888 completed  //////  0 min 1.02 sec
# 1812-679-2-2-Crossmodal-Visual-deep-(-6.36 mm)-TT1.1 ////// 531/888 completed  //////  0 min 1.17 sec
# 1813-679-2-2-Crossmodal-Visual-deep-(-6.36 mm)-TT1.2 ////// 532/888 completed  //////  0 min 1.02 sec
# 1814-679-2-2-Crossmodal-Visual-deep-(-6.36 mm)-TT1.3 ////// 533/888 completed  //////  0 min 1.11 sec
# 1815-679-2-2-Crossmodal-Visual-deep-(-6.24 mm)-TT2.1 ////// 534/888 completed  //////  0 min 0.97 sec
# 1816-679-2-2-Crossmodal-Visual-deep-(-6.24 mm)-TT2.2 ////// 535/888 completed  //////  0 min 1.06 sec
# 1818-679-2-2-Crossmodal-Visual-deep-(-6.24 mm)-TT3.1 ////// 537/888 completed  //////  0 min 1.83 sec
# 1819-679-2-2-Crossmodal-Visual-deep-(-4.56 mm)-TT11.1 ////// 538/888 completed  //////  0 min 1.04 sec
# 1820-679-2-2-Crossmodal-Visual-deep-(-4.56 mm)-TT11.2 ////// 539/888 completed  //////  0 min 1.27 sec
# 1822-679-2-2-Crossmodal-PER-deep-(-4.8 mm)-TT12.2 ////// 540/888 completed  //////  0 min 1.15 sec
# 1825-679-2-2-Crossmodal-Visual-deep-(-4.56 mm)-TT13.2 ////// 543/888 completed  //////  0 min 1.35 sec
# 1826-679-2-2-Crossmodal-Visual-deep-(-4.56 mm)-TT13.3 ////// 544/888 completed  //////  0 min 1.24 sec
# 1829-679-2-2-Crossmodal-Visual-deep-(-4.44 mm)-TT14.3 ////// 547/888 completed  //////  0 min 0.99 sec
# 1830-679-2-2-Crossmodal-Visual-deep-(-4.44 mm)-TT14.4 ////// 548/888 completed  //////  0 min 1.17 sec
# 1831-679-2-2-Crossmodal-Visual-deep-(-4.44 mm)-TT14.5 ////// 549/888 completed  //////  0 min 1.16 sec
# 1832-679-2-2-Crossmodal-Visual-deep-(-4.44 mm)-TT14.6 ////// 550/888 completed  //////  0 min 1.06 sec
# 1833-679-2-2-Crossmodal-Visual-deep-(-4.44 mm)-TT14.7 ////// 551/888 completed  //////  0 min 1.33 sec
# 1834-679-2-2-Crossmodal-Visual-deep-(-4.68 mm)-TT15.1 ////// 552/888 completed  //////  0 min 0.96 sec
# 1835-679-2-2-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.1 ////// 553/888 completed  //////  0 min 1.07 sec
# 1836-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.1 ////// 554/888 completed  //////  0 min 1.12 sec
# 1837-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.2 ////// 555/888 completed  //////  0 min 1.22 sec
# 1838-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.3 ////// 556/888 completed  //////  0 min 1.20 sec
# 1839-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.4 ////// 557/888 completed  //////  0 min 1.30 sec
# 1840-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.5 ////// 558/888 completed  //////  0 min 1.22 sec
# 1842-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT19.2 ////// 559/888 completed  //////  0 min 1.25 sec
# 1843-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT19.3 ////// 560/888 completed  //////  0 min 1.14 sec
# 1844-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT19.4 ////// 561/888 completed  //////  0 min 1.05 sec
# 1845-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT19.5 ////// 562/888 completed  //////  0 min 1.11 sec
# 1846-679-2-2-Crossmodal-Auditory-deep-(-5.4 mm)-TT19.6 ////// 563/888 completed  //////  0 min 1.58 sec
# 1848-679-2-2-Crossmodal-Auditory-deep-(-5.52 mm)-TT20.1 ////// 564/888 completed  //////  0 min 1.48 sec
# 1851-679-2-2-Crossmodal-Auditory-deep-(-5.64 mm)-TT21.3 ////// 566/888 completed  //////  0 min 1.05 sec
# 1855-679-2-2-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.1 ////// 568/888 completed  //////  0 min 3.97 sec
# 1857-679-3-3-Crossmodal-Visual-deep-(-6.36 mm)-TT1.1 ////// 569/888 completed  //////  0 min 2.21 sec
# 1858-679-3-3-Crossmodal-Visual-deep-(-6.24 mm)-TT2.1 ////// 570/888 completed  //////  0 min 1.49 sec
# 1859-679-3-3-Crossmodal-Visual-deep-(-6.24 mm)-TT2.2 ////// 571/888 completed  //////  0 min 1.10 sec
# 1860-679-3-3-Crossmodal-Visual-deep-(-6.24 mm)-TT3.1 ////// 572/888 completed  //////  0 min 1.28 sec
# 1861-679-3-3-Crossmodal-Visual-deep-(-4.56 mm)-TT11.1 ////// 573/888 completed  //////  0 min 1.13 sec
# 1864-679-3-3-Crossmodal-Visual-deep-(-4.56 mm)-TT13.1 ////// 576/888 completed  //////  0 min 1.95 sec
# 1865-679-3-3-Crossmodal-Visual-deep-(-4.56 mm)-TT13.2 ////// 577/888 completed  //////  0 min 2.03 sec
# 1867-679-3-3-Crossmodal-Visual-deep-(-4.56 mm)-TT13.4 ////// 578/888 completed  //////  0 min 1.05 sec
# 1868-679-3-3-Crossmodal-Visual-deep-(-4.56 mm)-TT13.5 ////// 579/888 completed  //////  0 min 1.09 sec
# 1871-679-3-3-Crossmodal-Visual-deep-(-4.44 mm)-TT14.1 ////// 582/888 completed  //////  0 min 1.04 sec
# 1872-679-3-3-Crossmodal-Visual-deep-(-4.44 mm)-TT14.2 ////// 583/888 completed  //////  0 min 1.65 sec
# 1873-679-3-3-Crossmodal-Visual-deep-(-4.44 mm)-TT14.3 ////// 584/888 completed  //////  0 min 1.18 sec
# 1875-679-3-3-Crossmodal-Visual-deep-(-4.44 mm)-TT14.5 ////// 585/888 completed  //////  0 min 1.24 sec
# 1876-679-3-3-Crossmodal-Visual-deep-(-4.44 mm)-TT14.6 ////// 586/888 completed  //////  0 min 1.49 sec
# 1877-679-3-3-Crossmodal-Visual-deep-(-4.68 mm)-TT15.1 ////// 587/888 completed  //////  0 min 1.56 sec
# 1878-679-3-3-Crossmodal-Visual-deep-(-4.68 mm)-TT15.2 ////// 588/888 completed  //////  0 min 1.25 sec
# 1880-679-3-3-Crossmodal-Visual-deep-(-4.68 mm)-TT15.4 ////// 589/888 completed  //////  0 min 1.13 sec
# 1881-679-3-3-Crossmodal-Visual-deep-(-4.68 mm)-TT15.5 ////// 590/888 completed  //////  0 min 1.07 sec
# 1883-679-3-3-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.2 ////// 591/888 completed  //////  0 min 1.26 sec
# 1884-679-3-3-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.1 ////// 592/888 completed  //////  0 min 1.49 sec
# 1885-679-3-3-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.2 ////// 593/888 completed  //////  0 min 1.25 sec
# 1886-679-3-3-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.3 ////// 594/888 completed  //////  0 min 1.19 sec
# 1887-679-3-3-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.4 ////// 595/888 completed  //////  0 min 1.51 sec
# 1888-679-3-3-Crossmodal-Auditory-deep-(-5.4 mm)-TT19.1 ////// 596/888 completed  //////  0 min 1.41 sec
# 1889-679-3-3-Crossmodal-Auditory-deep-(-5.4 mm)-TT19.2 ////// 597/888 completed  //////  0 min 1.53 sec
# 1892-679-3-3-Crossmodal-Visual-superficial-(-6.24 mm)-TT23.1 ////// 599/888 completed  //////  0 min 1.18 sec
# 1898-679-3-3-Crossmodal-Visual-superficial-(-6.24 mm)-TT23.7 ////// 601/888 completed  //////  0 min 1.11 sec
# 1899-679-3-3-Crossmodal-Visual-superficial-(-6.24 mm)-TT23.8 ////// 602/888 completed  //////  0 min 1.05 sec
# 1900-679-4-4-Crossmodal-Visual-deep-(-6.36 mm)-TT1.1 ////// 603/888 completed  //////  0 min 1.09 sec
# 1901-679-4-4-Crossmodal-Visual-deep-(-6.36 mm)-TT1.2 ////// 604/888 completed  //////  0 min 1.07 sec
# 1902-679-4-4-Crossmodal-Visual-deep-(-6.24 mm)-TT3.1 ////// 605/888 completed  //////  0 min 1.30 sec
# 1903-679-4-4-Crossmodal-Visual-deep-(-6.24 mm)-TT3.2 ////// 606/888 completed  //////  0 min 1.19 sec
# 1904-679-4-4-Crossmodal-Visual-deep-(-4.56 mm)-TT11.1 ////// 607/888 completed  //////  0 min 1.12 sec
# 1908-679-4-4-Crossmodal-PER-deep-(-4.8 mm)-TT12.3 ////// 610/888 completed  //////  0 min 1.21 sec
# 1910-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.1 ////// 612/888 completed  //////  0 min 1.42 sec
# 1911-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.2 ////// 613/888 completed  //////  0 min 1.27 sec
# 1912-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.3 ////// 614/888 completed  //////  0 min 1.26 sec
# 1913-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.4 ////// 615/888 completed  //////  0 min 1.31 sec
# 1914-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.5 ////// 616/888 completed  //////  0 min 1.18 sec
# 1915-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.6 ////// 617/888 completed  //////  0 min 1.13 sec
# 1916-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.7 ////// 618/888 completed  //////  0 min 1.09 sec
# 1917-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.8 ////// 619/888 completed  //////  0 min 1.12 sec
# 1918-679-4-4-Crossmodal-Visual-deep-(-4.44 mm)-TT14.9 ////// 620/888 completed  //////  0 min 1.10 sec
# 1919-679-4-4-Crossmodal-Visual-deep-(-4.68 mm)-TT15.1 ////// 621/888 completed  //////  0 min 0.97 sec
# 1920-679-4-4-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.1 ////// 622/888 completed  //////  0 min 1.12 sec
# 1921-679-4-4-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.2 ////// 623/888 completed  //////  0 min 1.00 sec
# 1922-679-4-4-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.1 ////// 624/888 completed  //////  0 min 1.27 sec
# 1923-679-4-4-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.2 ////// 625/888 completed  //////  0 min 1.07 sec
# 1924-679-4-4-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.3 ////// 626/888 completed  //////  0 min 1.03 sec
# 1925-679-4-4-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.4 ////// 627/888 completed  //////  0 min 1.26 sec
# 1926-679-4-4-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.5 ////// 628/888 completed  //////  0 min 1.29 sec
# 1927-679-4-4-Crossmodal-Auditory-deep-(-5.52 mm)-TT20.1 ////// 629/888 completed  //////  0 min 1.26 sec
# 1933-679-5-5-Crossmodal-Visual-deep-(-6.36 mm)-TT1.1 ////// 631/888 completed  //////  0 min 1.28 sec
# 1934-679-5-5-Crossmodal-Visual-deep-(-6.36 mm)-TT1.2 ////// 632/888 completed  //////  0 min 1.02 sec
# 1937-679-5-5-Crossmodal-Visual-deep-(-6.24 mm)-TT3.1 ////// 635/888 completed  //////  0 min 1.11 sec
# 1939-679-5-5-Crossmodal-Visual-deep-(-4.56 mm)-TT13.1 ////// 636/888 completed  //////  0 min 1.44 sec
# 1941-679-5-5-Crossmodal-Visual-deep-(-4.44 mm)-TT14.2 ////// 637/888 completed  //////  0 min 1.12 sec
# 1942-679-5-5-Crossmodal-Visual-deep-(-4.44 mm)-TT14.3 ////// 638/888 completed  //////  0 min 1.03 sec
# 1943-679-5-5-Crossmodal-Visual-deep-(-4.44 mm)-TT14.4 ////// 639/888 completed  //////  0 min 1.09 sec
# 1944-679-5-5-Crossmodal-Visual-deep-(-4.44 mm)-TT14.5 ////// 640/888 completed  //////  0 min 1.25 sec
# 1945-679-5-5-Crossmodal-Visual-deep-(-4.44 mm)-TT14.6 ////// 641/888 completed  //////  0 min 0.99 sec
# 1946-679-5-5-Crossmodal-Visual-deep-(-4.44 mm)-TT14.7 ////// 642/888 completed  //////  0 min 1.00 sec
# 1947-679-5-5-Crossmodal-Visual-deep-(-4.44 mm)-TT14.8 ////// 643/888 completed  //////  0 min 0.94 sec
# 1948-679-5-5-Crossmodal-Visual-deep-(-4.44 mm)-TT14.9 ////// 644/888 completed  //////  0 min 1.19 sec
# 1949-679-5-5-Crossmodal-Visual-deep-(-4.68 mm)-TT15.1 ////// 645/888 completed  //////  0 min 1.31 sec
# 1950-679-5-5-Crossmodal-Visual-deep-(-4.68 mm)-TT15.2 ////// 646/888 completed  //////  0 min 1.16 sec
# 1951-679-5-5-Crossmodal-Visual-deep-(-4.56 mm)-TT16.1 ////// 647/888 completed  //////  0 min 1.20 sec
# 1952-679-5-5-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.1 ////// 648/888 completed  //////  0 min 1.12 sec
# 1953-679-5-5-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.1 ////// 649/888 completed  //////  0 min 1.13 sec
# 1954-679-5-5-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.2 ////// 650/888 completed  //////  0 min 1.06 sec
# 1955-679-5-5-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.3 ////// 651/888 completed  //////  0 min 1.07 sec
# 1956-679-5-5-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.4 ////// 652/888 completed  //////  0 min 0.92 sec
# 1957-679-5-5-Crossmodal-Auditory-deep-(-5.4 mm)-TT19.1 ////// 653/888 completed  //////  0 min 1.20 sec
# 1958-679-5-5-Crossmodal-Auditory-deep-(-5.52 mm)-TT20.1 ////// 654/888 completed  //////  0 min 1.19 sec
# 1960-679-5-5-Crossmodal-Auditory-deep-(-5.64 mm)-TT21.2 ////// 656/888 completed  //////  0 min 1.13 sec
# 1961-679-5-5-Crossmodal-Auditory-deep-(-5.64 mm)-TT21.3 ////// 657/888 completed  //////  0 min 1.06 sec
# 1963-679-5-5-Crossmodal-Auditory-deep-(-5.64 mm)-TT21.5 ////// 658/888 completed  //////  0 min 0.96 sec
# 1965-679-5-5-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.1 ////// 659/888 completed  //////  0 min 1.17 sec
# 1967-679-6-6-Crossmodal-Visual-deep-(-6.36 mm)-TT1.1 ////// 660/888 completed  //////  0 min 1.20 sec
# 1968-679-6-6-Crossmodal-Visual-deep-(-6.36 mm)-TT1.2 ////// 661/888 completed  //////  0 min 1.37 sec
# 1969-679-6-6-Crossmodal-Visual-deep-(-6.36 mm)-TT1.3 ////// 662/888 completed  //////  0 min 1.16 sec
# 1971-679-6-6-Crossmodal-Visual-deep-(-6.24 mm)-TT2.1 ////// 664/888 completed  //////  0 min 1.13 sec
# 1972-679-6-6-Crossmodal-Visual-deep-(-6.24 mm)-TT2.2 ////// 665/888 completed  //////  0 min 1.12 sec
# 1973-679-6-6-Crossmodal-Visual-deep-(-6.24 mm)-TT2.3 ////// 666/888 completed  //////  0 min 1.07 sec
# 1974-679-6-6-Crossmodal-Visual-deep-(-6.24 mm)-TT2.4 ////// 667/888 completed  //////  0 min 1.12 sec
# 1975-679-6-6-Crossmodal-Visual-deep-(-6.24 mm)-TT2.5 ////// 668/888 completed  //////  0 min 4.00 sec
# 1976-679-6-6-Crossmodal-Visual-deep-(-6.24 mm)-TT2.6 ////// 669/888 completed  //////  0 min 0.92 sec
# 1977-679-6-6-Crossmodal-Visual-deep-(-6.24 mm)-TT3.1 ////// 670/888 completed  //////  0 min 1.01 sec
# 1979-679-6-6-Crossmodal-Visual-deep-(-4.56 mm)-TT13.1 ////// 672/888 completed  //////  0 min 1.04 sec
# 1981-679-6-6-Crossmodal-Visual-deep-(-4.44 mm)-TT14.1 ////// 674/888 completed  //////  0 min 1.32 sec
# 1983-679-6-6-Crossmodal-Visual-deep-(-4.44 mm)-TT14.3 ////// 675/888 completed  //////  0 min 1.11 sec
# 1984-679-6-6-Crossmodal-Visual-deep-(-4.44 mm)-TT14.4 ////// 676/888 completed  //////  0 min 1.44 sec
# 1985-679-6-6-Crossmodal-Visual-deep-(-4.44 mm)-TT14.5 ////// 677/888 completed  //////  0 min 1.22 sec
# 1986-679-6-6-Crossmodal-Visual-deep-(-4.44 mm)-TT14.6 ////// 678/888 completed  //////  0 min 1.42 sec
# 1987-679-6-6-Crossmodal-Visual-deep-(-4.44 mm)-TT14.7 ////// 679/888 completed  //////  0 min 1.37 sec
# 1989-679-6-6-Crossmodal-Visual-deep-(-4.68 mm)-TT15.1 ////// 680/888 completed  //////  0 min 1.33 sec
# 1992-679-6-6-Crossmodal-Visual-deep-(-4.68 mm)-TT15.4 ////// 681/888 completed  //////  0 min 1.42 sec
# 1993-679-6-6-Crossmodal-Visual-deep-(-4.68 mm)-TT15.5 ////// 682/888 completed  //////  0 min 1.38 sec
# 1994-679-6-6-Crossmodal-Visual-deep-(-4.56 mm)-TT16.1 ////// 683/888 completed  //////  0 min 1.26 sec
# 1995-679-6-6-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.1 ////// 684/888 completed  //////  0 min 1.37 sec
# 1997-679-6-6-Crossmodal-Auditory-deep-(-5.28 mm)-TT17.3 ////// 685/888 completed  //////  0 min 1.44 sec
# 1999-679-6-6-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.1 ////// 686/888 completed  //////  0 min 1.79 sec
# 2000-679-6-6-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.2 ////// 687/888 completed  //////  0 min 1.57 sec
# 2001-679-6-6-Crossmodal-Auditory-deep-(-5.4 mm)-TT18.3 ////// 688/888 completed  //////  0 min 1.65 sec
# 2002-679-6-6-Crossmodal-Auditory-deep-(-5.52 mm)-TT20.1 ////// 689/888 completed  //////  0 min 1.34 sec
# 2003-679-6-6-Crossmodal-Auditory-deep-(-5.64 mm)-TT21.1 ////// 690/888 completed  //////  0 min 1.33 sec
# 2004-679-6-6-Crossmodal-Auditory-deep-(-5.64 mm)-TT21.2 ////// 691/888 completed  //////  0 min 1.62 sec
# 2005-679-6-6-Crossmodal-Auditory-deep-(-6.64 mm)-TT22.1 ////// 692/888 completed  //////  0 min 1.22 sec
# 2181-699-1-1-Crossmodal-Visual-deep-(-6.96 mm)-TT1.1 ////// 693/888 completed  //////  0 min 1.16 sec
# 2184-699-1-1-Crossmodal-Visual-deep-(-6.72 mm)-TT2.1 ////// 695/888 completed  //////  0 min 1.14 sec
# 2185-699-1-1-Crossmodal-Visual-deep-(-6.36 mm)-TT3.1 ////// 696/888 completed  //////  0 min 1.18 sec
# 2188-699-1-1-Crossmodal-PER-deep-(-5.76 mm)-TT5.3 ////// 698/888 completed  //////  0 min 1.17 sec
# 2190-699-1-1-Crossmodal-PER-deep-(-5.52 mm)-TT7.1 ////// 700/888 completed  //////  0 min 1.17 sec
# 2192-699-1-1-Crossmodal-PER-deep-(-5.52 mm)-TT7.3 ////// 701/888 completed  //////  0 min 1.49 sec
# 2195-699-1-1-Crossmodal-Tev-deep-(-4.8 mm)-TT10.1 ////// 702/888 completed  //////  0 min 1.41 sec
# 2197-699-1-1-Crossmodal-Tev-deep-(-4.8 mm)-TT10.3 ////// 703/888 completed  //////  0 min 1.66 sec
# 2199-699-1-1-Crossmodal-PER-deep-(-4.68 mm)-TT11.2 ////// 705/888 completed  //////  0 min 1.46 sec
# 2201-699-1-1-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.1 ////// 707/888 completed  //////  0 min 1.61 sec
# 2203-699-1-1-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.3 ////// 708/888 completed  //////  0 min 1.25 sec
# 2204-699-1-1-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.4 ////// 709/888 completed  //////  0 min 1.40 sec
# 2206-699-1-1-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 711/888 completed  //////  0 min 1.26 sec
# 2207-699-1-1-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 712/888 completed  //////  0 min 1.16 sec
# 2209-699-1-1-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.1 ////// 714/888 completed  //////  0 min 1.07 sec
# 2210-699-1-1-Crossmodal-Tev-deep-(-4.92 mm)-TT16.1 ////// 715/888 completed  //////  0 min 1.15 sec
# 2219-699-1-1-Crossmodal-Visual-deep-(-6.48 mm)-TT24.1 ////// 724/888 completed  //////  0 min 1.44 sec
# 2220-699-2-2-Crossmodal-Visual-deep-(-6.72 mm)-TT2.1 ////// 725/888 completed  //////  0 min 1.25 sec
# 2222-699-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT7.1 ////// 727/888 completed  //////  0 min 1.23 sec
# 2225-699-2-2-Crossmodal-PER-deep-(-5.52 mm)-TT8.1 ////// 729/888 completed  //////  0 min 1.54 sec
# 2227-699-2-2-Crossmodal-PER-deep-(-4.68 mm)-TT11.1 ////// 731/888 completed  //////  0 min 1.82 sec
# 2229-699-2-2-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.2 ////// 733/888 completed  //////  0 min 2.16 sec
# 2230-699-2-2-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.3 ////// 734/888 completed  //////  0 min 1.80 sec
# 2232-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 735/888 completed  //////  0 min 1.25 sec
# 2233-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.3 ////// 736/888 completed  //////  0 min 2.19 sec
# 2234-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.4 ////// 737/888 completed  //////  0 min 1.17 sec
# 2236-699-2-2-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 739/888 completed  //////  0 min 1.44 sec
# 2237-699-2-2-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 740/888 completed  //////  0 min 1.42 sec
# 2238-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.1 ////// 741/888 completed  //////  0 min 1.28 sec
# 2239-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.2 ////// 742/888 completed  //////  0 min 1.33 sec
# 2241-699-2-2-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.4 ////// 744/888 completed  //////  0 min 1.40 sec
# 2242-699-2-2-Crossmodal-Tev-deep-(-4.92 mm)-TT16.1 ////// 745/888 completed  //////  0 min 1.19 sec
# 2246-699-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT17.4 ////// 749/888 completed  //////  0 min 1.09 sec
# 2247-699-2-2-Crossmodal-PER-deep-(-5.28 mm)-TT17.5 ////// 750/888 completed  //////  0 min 1.33 sec
# 2254-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.2 ////// 755/888 completed  //////  0 min 1.62 sec
# 2255-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.3 ////// 756/888 completed  //////  0 min 1.63 sec
# 2256-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.4 ////// 757/888 completed  //////  0 min 1.50 sec
# 2258-699-2-2-Crossmodal-Tev-deep-(-6.24 mm)-TT22.6 ////// 759/888 completed  //////  0 min 1.01 sec
# 2259-699-3-3-Crossmodal-Visual-deep-(-6.96 mm)-TT1.1 ////// 760/888 completed  //////  0 min 1.18 sec
# 2261-699-3-3-Crossmodal-PER-deep-(-5.76 mm)-TT5.2 ////// 762/888 completed  //////  0 min 1.28 sec
# 2263-699-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT7.2 ////// 764/888 completed  //////  0 min 1.43 sec
# 2265-699-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT7.4 ////// 765/888 completed  //////  0 min 1.80 sec
# 2266-699-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT8.1 ////// 766/888 completed  //////  0 min 1.17 sec
# 2267-699-3-3-Crossmodal-PER-deep-(-5.52 mm)-TT8.2 ////// 767/888 completed  //////  0 min 1.53 sec
# 2269-699-3-3-Crossmodal-PER-deep-(-5.2 mm)-TT9.2 ////// 769/888 completed  //////  0 min 1.88 sec
# 2273-699-3-3-Crossmodal-PER-deep-(-4.68 mm)-TT11.2 ////// 773/888 completed  //////  0 min 1.86 sec
# 2275-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.2 ////// 774/888 completed  //////  0 min 1.11 sec
# 2276-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.3 ////// 775/888 completed  //////  0 min 1.50 sec
# 2277-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.4 ////// 776/888 completed  //////  0 min 1.52 sec
# 2279-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.1 ////// 777/888 completed  //////  0 min 1.46 sec
# 2280-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 778/888 completed  //////  0 min 1.22 sec
# 2281-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.1 ////// 779/888 completed  //////  0 min 1.57 sec
# 2282-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 780/888 completed  //////  0 min 1.44 sec
# 2283-699-3-3-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 781/888 completed  //////  0 min 1.32 sec
# 2285-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.2 ////// 783/888 completed  //////  0 min 1.13 sec
# 2287-699-3-3-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.4 ////// 785/888 completed  //////  0 min 1.12 sec
# 2288-699-3-3-Crossmodal-PER-deep-(-4.92 mm)-TT16.1 ////// 786/888 completed  //////  0 min 1.13 sec
# 2289-699-3-3-Crossmodal-PER-deep-(-4.92 mm)-TT16.2 ////// 787/888 completed  //////  0 min 1.21 sec
# 2294-699-3-3-Crossmodal-Tev-deep-(-5.64 mm)-TT18.1 ////// 792/888 completed  //////  0 min 1.31 sec
# 2295-699-3-3-Crossmodal-Tev-deep-(-5.64 mm)-TT18.2 ////// 793/888 completed  //////  0 min 1.23 sec
# 2300-699-3-3-Crossmodal-Visual-superficial-(-6.36 mm)-TT23.1 ////// 798/888 completed  //////  0 min 1.28 sec
# 2301-699-4-4-Crossmodal-Visual-deep-(-6.72 mm)-TT2.1 ////// 799/888 completed  //////  0 min 1.77 sec
# 2302-699-4-4-Crossmodal-Visual-deep-(-6.72 mm)-TT2.2 ////// 800/888 completed  //////  0 min 2.37 sec
# 2311-699-4-4-Crossmodal-PER-deep-(-5.2 mm)-TT9.3 ////// 806/888 completed  //////  0 min 2.28 sec
# 2313-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.1 ////// 808/888 completed  //////  0 min 2.57 sec
# 2316-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.1 ////// 809/888 completed  //////  0 min 1.88 sec
# 2317-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 810/888 completed  //////  0 min 1.45 sec
# 2318-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.3 ////// 811/888 completed  //////  0 min 1.14 sec
# 2319-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.4 ////// 812/888 completed  //////  0 min 1.67 sec
# 2322-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 815/888 completed  //////  0 min 1.55 sec
# 2323-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.3 ////// 816/888 completed  //////  0 min 1.84 sec
# 2324-699-4-4-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.4 ////// 817/888 completed  //////  0 min 1.50 sec
# 2325-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.1 ////// 818/888 completed  //////  0 min 1.44 sec
# 2326-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.2 ////// 819/888 completed  //////  0 min 1.54 sec
# 2328-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.4 ////// 821/888 completed  //////  0 min 1.16 sec
# 2329-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.5 ////// 822/888 completed  //////  0 min 1.05 sec
# 2332-699-4-4-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.8 ////// 825/888 completed  //////  0 min 1.19 sec
# 2335-699-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT17.1 ////// 828/888 completed  //////  0 min 1.09 sec
# 2336-699-4-4-Crossmodal-PER-deep-(-5.28 mm)-TT17.2 ////// 829/888 completed  //////  0 min 1.36 sec
# 2344-699-4-4-Crossmodal-Visual-deep-(-6.48 mm)-TT24.1 ////// 834/888 completed  //////  0 min 1.12 sec
# 2345-699-4-4-Crossmodal-Visual-deep-(-6.48 mm)-TT24.2 ////// 835/888 completed  //////  0 min 1.40 sec
# 2346-699-4-4-Crossmodal-Visual-deep-(-6.48 mm)-TT24.3 ////// 836/888 completed  //////  0 min 1.41 sec
# 2348-699-5-5-Crossmodal-Visual-deep-(-6.72 mm)-TT2.1 ////// 838/888 completed  //////  0 min 1.47 sec
# 2349-699-5-5-Crossmodal-PER-deep-(-5.52 mm)-TT8.1 ////// 839/888 completed  //////  0 min 1.19 sec
# 2352-699-5-5-Crossmodal-PER-deep-(-5.2 mm)-TT9.3 ////// 842/888 completed  //////  0 min 1.18 sec
# 2353-699-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT10.1 ////// 843/888 completed  //////  0 min 1.67 sec
# 2356-699-5-5-Crossmodal-PER-deep-(-4.8 mm)-TT10.4 ////// 845/888 completed  //////  0 min 1.33 sec
# 2359-699-5-5-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.1 ////// 847/888 completed  //////  0 min 4.95 sec
# 2360-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.1 ////// 848/888 completed  //////  0 min 1.28 sec
# 2361-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.2 ////// 849/888 completed  //////  0 min 1.28 sec
# 2362-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.3 ////// 850/888 completed  //////  0 min 1.27 sec
# 2363-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.4 ////// 851/888 completed  //////  0 min 1.20 sec
# 2364-699-5-5-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.1 ////// 852/888 completed  //////  0 min 1.21 sec
# 2365-699-5-5-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 853/888 completed  //////  0 min 1.14 sec
# 2367-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.1 ////// 855/888 completed  //////  0 min 1.27 sec
# 2368-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.2 ////// 856/888 completed  //////  0 min 1.41 sec
# 2369-699-5-5-Crossmodal-Auditory-deep-(-4.68 mm)-TT15.3 ////// 857/888 completed  //////  0 min 1.54 sec
# 2371-699-5-5-Crossmodal-PER-deep-(-4.92 mm)-TT16.1 ////// 859/888 completed  //////  0 min 1.33 sec
# 2373-699-5-5-Crossmodal-PER-deep-(-4.92 mm)-TT16.3 ////// 861/888 completed  //////  0 min 2.44 sec
# 2376-699-5-5-Crossmodal-PER-deep-(-5.28 mm)-TT17.3 ////// 864/888 completed  //////  0 min 1.70 sec
# 2380-699-5-5-Crossmodal-PER-deep-(-5.28 mm)-TT17.7 ////// 865/888 completed  //////  0 min 1.13 sec
# 2383-699-5-5-Crossmodal-Visual-superficial-(-6.36 mm)-TT23.1 ////// 868/888 completed  //////  0 min 1.38 sec
# 2385-699-6-6-Crossmodal-PER-superficial-(-5.52 mm)-TT7.1 ////// 869/888 completed  //////  0 min 1.31 sec
# 2388-699-6-6-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.1 ////// 872/888 completed  //////  0 min 1.51 sec
# 2389-699-6-6-Crossmodal-Auditory-deep-(-4.56 mm)-TT12.2 ////// 873/888 completed  //////  0 min 1.87 sec
# 2391-699-6-6-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.1 ////// 874/888 completed  //////  0 min 1.13 sec
# 2394-699-6-6-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.4 ////// 877/888 completed  //////  0 min 1.04 sec
# 2395-699-6-6-Crossmodal-Auditory-deep-(-4.68 mm)-TT13.5 ////// 878/888 completed  //////  0 min 1.13 sec
# 2396-699-6-6-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.1 ////// 879/888 completed  //////  0 min 1.15 sec
# 2397-699-6-6-Crossmodal-Auditory-deep-(-4.56 mm)-TT14.2 ////// 880/888 completed  //////  0 min 1.02 sec
# 2402-699-6-6-Crossmodal-PER-deep-(-5.28 mm)-TT17.5 ////// 882/888 completed  //////  0 min 0.94 sec
# 2403-699-6-6-Crossmodal-PER-deep-(-5.28 mm)-TT17.6 ////// 883/888 completed  //////  0 min 1.03 sec
# 2405-699-6-6-Crossmodal-Visual-deep-(-6.12 mm)-TT21.1 ////// 885/888 completed  //////  0 min 1.41 sec
# 2406-699-6-6-Crossmodal-Visual-deep-(-6.12 mm)-TT21.2 ////// 886/888 completed  //////  0 min 1.17 sec
# 2407-699-6-6-Crossmodal-Visual-deep-(-6.12 mm)-TT21.3 ////// 887/888 completed  //////  0 min 1.10 sec
# 2409-699-6-6-Crossmodal-Visual-superficial-(-6.36 mm)-TT23.1 ////// 888/888 completed  //////  0 min 1.07 sec
# CPU times: total: 7min 22s
# Wall time: 12min 47s

# %%
f.close()
s.close()
print('END')
# Out:
# END
